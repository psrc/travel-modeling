# %%
import pandas as pd

# %%
df = pd.read_excel(r'R:\SoundCastDocuments\AVsTravelandLandUse\model results\Integrated Results\IntegratedRunResults.xlsx', 
                   sheetname='LandUse - Population')

# %%
# perform a t-test

from scipy.stats import ttest_ind

# cat1 = df[df['County']=='King']
# cat2 = df[df['County']=='King']
cat1 = df
cat2 = df

ttest_ind(cat1['integrated_av_2050'], cat2['integrated_2050'])
# Out:
# Ttest_indResult(statistic=0.00020507773747616755, pvalue=0.9998364654372774)

# %%
df['integrated_av_2050']
# Out:
#         County         Indicator Geography   ID                    Name  \
# 9         King  Total Population      city    9                 Seattle
# 13        King  Total Population      city   13                Bellevue
# 84      Pierce  Total Population      city   85                Puyallup
# 93   Snohomish  Total Population      city   94                Lynnwood
# 12        King  Total Population      city   12                  Renton
# 15        King  Total Population      city   15                 Redmond
# 86      Pierce  Total Population      city   87                Edgewood
# 105  Snohomish  Total Population      city  106              Marysville
# 107  Snohomish  Total Population      city  108           Mukilteo MUGA
# 67      Kitsap  Total Population      city   68      Central Kitsap UGA
# 18        King  Total Population      city   18              Des Moines
# 20        King  Total Population      city   20             Federal Way
# ...
