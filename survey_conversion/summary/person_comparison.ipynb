# %% [raw]
# ---
# title: Person Comparison
# date: today
# ---

# %%
# Compare new survey to old
import os
import toml
import pandas as pd
from functions import load_data, plot_display

config = toml.load(os.path.join(os.getcwd(), 'summary_configuration.toml'))

# %%
print(config['survey_1_name']+': '+config['survey_1_dir'])
print(config['survey_2_name']+': '+config['survey_2_dir'])

# %%
df = load_data('_person.tsv', config['survey_1_dir'], config['survey_2_dir'], 
               config['survey_1_name'], config['survey_2_name'])

# %% [raw]
# ## Tour Characteristics

# %% [raw]
# ::: {.panel-tabset}
#
# ### Persons (Weighted)

# %%
for col in ['pptyp','pagey','pgend','pwtyp','pstyp','ptpass']:
    plot_display(df, index=col, columns='source', aggfunc='sum', values='psexpfac')

# %%
### Persons (Unweighted)

# %%
for col in ['pptyp','pagey','pgend','pwtyp','pstyp','ptpass']:
    plot_display(df, index=col, columns='source', aggfunc='count', values='psexpfac')
