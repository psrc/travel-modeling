# %%
# Compare new survey to old
import os
import toml
import pandas as pd
from functions import load_data, plot_display

config = toml.load(os.path.join(os.getcwd(), 'summary_configuration.toml'))

# %%
print(config['survey_1_name']+': '+config['survey_1_dir'])
print(config['survey_2_name']+': '+config['survey_2_dir'])
# Out:
# NEW: R:/e2projects_two/2018_base_year/survey/daysim_format/revised
# RSG: R:/e2projects_two/SoundCast/Inputs/dev/base_year/2018/survey\RSG_version

# %%
df = load_data('_trip.tsv', config['survey_1_dir'], config['survey_2_dir'], 
               config['survey_1_name'], config['survey_2_name'])

# %% [raw]
# ## Trip Characteristics

# %% [raw]
# ::: {.panel-tabset}
#
# ### Trips (Weighted)

# %%
for col in ['tour','half','tseg','oadtyp','dadtyp','pathtype','dorp']:
    plot_display(df, index=col, columns='source', aggfunc='sum', values='trexpfac')

# %% [raw]
# ### Trips (Unweighted)

# %%
for col in ['tour','half','tseg','oadtyp','dadtyp','pathtype','dorp']:
    plot_display(df, index=col, columns='source', aggfunc='count', values='trexpfac')

# %% [raw]
# :::

# %% [raw]
# ::: {.panel-tabset}
#
# ### Trip Mode and Purpose (Weighted)

# %%
for col in ['mode','opurp','dpurp']:
    plot_display(df, index=col, columns='source', aggfunc='sum', values='trexpfac')

# %% [raw]
# ### Trip Mode and Purpose (Unweighted)

# %%
for col in ['mode','opurp','dpurp']:
    plot_display(df, index=col, columns='source', aggfunc='count', values='trexpfac')

# %% [raw]
# :::
