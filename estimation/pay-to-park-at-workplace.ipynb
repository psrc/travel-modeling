# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Pay to Park at Workplace
# ### Notes
# - reversed sign on fraction of employment gov, from + in 2006 to - in 2014; t-stat lower for 2014, but still high at over 2; could indicate that more government employers are not paying for parking and instead offering transit benefits; or cutbacks stopped paying for parking. Negative relationship would make sense in that case - as concentration of gov workers increases, likelihood of being offered paid parking decreases.
# - MsgIncome (missing income) changed signs, with slightly higher t-stat in 2014, + coefficient in 2014; no intuition about if this is correct or not, could be that missing income suggests high income that denotes paid parking as perk for well-paid jobs
# - part-time is negative in 2014 vs + in 2006, with higher 2014 t-stat. Change could be due to slashed benefits for part-time workers since the recession
# - off-street parking is significant in 2014

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\with_transit_sub_mode\results\PayToParkAtWork'
dir_06 = r'R:\SoundCast\releases\soundcast_release_c1\inputs\coefficients'

fname_14 = 'PayToParkAtWorkplaceModel.F12'
fname_06 = 'PayToParkAtWorkplaceModel_psrcper1.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# Paid_Const      1  Paid_Const              F -3.208013           0.338167
# PartTime        2    PartTime              F -0.555381           0.159329
# OtherWkr        3    OtherWkr              F -0.256053           0.554113
# HHIncomeK       4   HHIncomeK              F  0.001056           0.000782
# MsgIncome       5   MsgIncome              F  0.295702           0.202946
# LnTotEmp1       6   LnTotEmp1              F  0.202181           0.033400
# LnDS/Emp1       7   LnDS/Emp1              F -0.068886           0.017032
# PsrkCost1       8   PsrkCost1              T  0.000000           0.000000
# FracEmpGov      9  FracEmpGov              F -0.588472           0.270103
# FracEmpEdu     12  FracEmpEdu              F -1.423595           0.359976
#
#              t-stat_14 id_06 constrained_06  value_06  standard error_06  \
# coefficient
# Paid_Const    9.486490     1              F -2.232981           0.292707
# PartTime      3.485746     2              F  0.353353           0.128293
# OtherWkr      0.462095     3              F  0.566335           0.170110
# HHIncomeK     1.350609     4              F -0.003535           0.001496
# MsgIncome     1.457054     5              F -0.315232           0.320795
# LnTotEmp1     6.053407     6              F  0.108336           0.034200
# LnDS/Emp1     4.044634     7              F  0.098789           0.023910
# PsrkCost1          NaN     8              T  0.000000           0.000000
# FracEmpGov    2.178693     9              F  1.433759           0.377194
# FracEmpEdu    3.954695    12              F -0.596336           0.308400
#
#              t-stat_06
# coefficient
# Paid_Const    7.628737
# PartTime      2.754272
# OtherWkr      3.329221
# HHIncomeK     2.363633
# MsgIncome     0.982656
# LnTotEmp1     3.167725
# LnDS/Emp1     4.131626
# PsrkCost1          NaN
# FracEmpGov    3.801124
# FracEmpEdu    1.933643
