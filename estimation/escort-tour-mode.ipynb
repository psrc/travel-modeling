# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Escort Tour Mode
# ### Notes:
# - Sign change on variables, presently kept in model becase t-stat > ~2:
#   - wk-hhdas (walk mode & number of children of driving age in HH)
#   - wk-ageo50 (walk mode & age over 50)
# - Logsum was > 1 (1.687) in estimation, and was constrained based on suggestion by Mark B.
# - Why were bi-const and hov-const constrained in 2006?
# - timeutil coefficient is very low compared to 2006

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\with_transit_sub_mode\results\EscortTourMode'
dir_06 = r'R:\SoundCastDocuments\2006Estimation\personbased_estimationfiles\newer_coeff_outputs'
# dir_14_old = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results_archive\WithNodeToNodeDistances\EscortTourModeModel\Iteration 1'

fname_14 = 'EscortTourModeModel.F12'
fname_06 = 'EscortTourModeModel_psrcper1.F12'
# fname_14_old = 'EscortTourModeModel.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)
# df_14_old = load_f12(dir_14_old, fname_14_old)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])
# df = compare_df(df_14,df_14_old,suffixes=['_14','_14_old'])

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# timeutil        2    timeutil              F  0.154250           0.028403
# s3-const       30    s3-const              F  1.971936           0.325118
# s3-hhcu5       31    s3-hhcu5              F  1.355630           0.116510
# s3-hh515       32    s3-hh515              F  0.881252           0.083012
# s3-hhdas       33    s3-hhdas              F  0.476626           0.103850
# s2-const       40    s2-const              F  3.434270           0.327471
# sr-nocars      41   sr-nocars              F -3.364465           0.661353
# sr-carsltd     42  sr-carsltd              F  0.016254           0.133711
# hov-const      50   hov-const              F  0.213104           0.391259
# bi-const       60    bi-const              F -1.786108           0.533887
# wk-ageo50      73   wk-ageo50              F  0.190278           0.404192
# wk-dintd       76    wk-dintd              F  0.006464           0.002181
# wk-hhcu5       81    wk-hhcu5              F  1.348634           0.209313
# wk-hh515       82    wk-hh515              F  1.169050           0.142652
# wk-hhdas       83    wk-hhdas              F  0.294229           0.227706
#
#              t-stat_14 id_06 constrained_06   value_06  standard error_06  \
# coefficient
# timeutil      5.430665     2              F   2.294432           0.121538
# s3-const      6.065296    30              F  -0.929365           0.319546
# s3-hhcu5     11.635348    31              F   1.335395           0.075738
# s3-hh515     10.615994    32              F   0.529875           0.041777
# s3-hhdas      4.589573    33              F   0.276831           0.106871
# s2-const     10.487252    40              F  -0.125647           0.322421
# sr-nocars     5.087248    41              T  -5.914000           0.000000
# sr-carsltd    0.121560    42              F   0.017161           0.102197
# hov-const     0.544662    50              T -10.000000           0.000000
# bi-const      3.345480    60              T -10.000000           0.000000
# wk-ageo50     0.470760    73              F  -2.302936           0.465283
# wk-dintd      2.964063    76              T   0.000000           0.000000
# wk-hhcu5      6.443131    81              F   0.550408           0.200152
# wk-hh515      8.195134    82              F   0.223274           0.139720
# wk-hhdas      1.292141    83              F  -3.804883           0.930822
#
#              t-stat_06
# coefficient
# timeutil     18.878356
# s3-const      2.908396
# s3-hhcu5     17.631663
# s3-hh515     12.683352
# s3-hhdas      2.590317
# s2-const      0.389700
# sr-nocars          inf
# sr-carsltd    0.167919
# hov-const          inf
# bi-const           inf
# wk-ageo50     4.949537
# wk-dintd           NaN
# wk-hhcu5      2.749954
# wk-hh515      1.598012
# wk-hhdas      4.087659
