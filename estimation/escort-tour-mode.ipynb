# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Escort Tour Mode

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results\EscortTourModeModel'
dir_06 = r'R:\SoundCast\releases\soundcast_release_c1\inputs\coefficients'
dir_14_old = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results_archive\WithNodeToNodeDistances\EscortTourModeModel\Iteration 1'

fname_14 = 'EscortTourModeModel.F12'
fname_06 = 'EscortTourModeModel_psrcper1.F12'
fname_14_old = 'EscortTourModeModel.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)
df_14_old = load_f12(dir_14_old, fname_14_old)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])
# df = compare_df(df_14,df_14_old,suffixes=['_14','_14_old'])
# Out:
# Axes(0.125,0.125;0.775x0.775)
# ['t-stat_14', 't-stat_06']
# Axes(0.125,0.125;0.775x0.775)

# %% [markdown]
# ### Notes:
# - Theta0999 and Theta0099 are similar variables representing a logsum - not sure why the names have changed slightly.
# - Sign change on variables, presently kept in model becase t-stat > ~2:
#   - wk-hhdas (walk mode & number of children of driving age in HH)
#   - wk-ageo50 (walk mode & age over 50)
# - Logsum was > 1 (1.687) in estimation, and was constrained based on suggestion by Mark B.
# - Why were bi-const and hov-const constrained in 2006?
# - timeutil coefficient is very low compared to 2006

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# timeutil        2    timeutil              F  0.154239           0.028402
# s3-const       30    s3-const              F  1.971933           0.325114
# s3-hhcu5       31    s3-hhcu5              F  1.355632           0.116509
# s3-hh515       32    s3-hh515              F  0.881253           0.083012
# s3-hhdas       33    s3-hhdas              F  0.476637           0.103850
# s2-const       40    s2-const              F  3.434256           0.327467
# sr-nocars      41   sr-nocars              F -3.364310           0.661311
# sr-carsltd     42  sr-carsltd              F  0.016279           0.133710
# hov-const      50   hov-const              F  0.213144           0.391250
# bi-const       60    bi-const              F -1.783324           0.533585
# wk-ageo50      73   wk-ageo50              F  0.190270           0.404191
# wk-dintd       76    wk-dintd              F  0.006464           0.002181
# wk-hhcu5       81    wk-hhcu5              F  1.348627           0.209310
# wk-hh515       82    wk-hh515              F  1.169048           0.142650
# wk-hhdas       83    wk-hhdas              F  0.294230           0.227705
# Theta0099      99   Theta0099              T  1.000000           0.000000
# Theta0999     NaN   Theta0999            NaN       NaN                NaN
#
#              t-stat_14 id_06 constrained_06   value_06  standard error_06  \
# coefficient
# timeutil      5.430531     2              F   2.594432           0.121538
# s3-const      6.065365    30              F  -0.989365           0.319546
# s3-hhcu5     11.635391    31              F   1.335395           0.075738
# s3-hh515     10.616018    32              F   0.529875           0.041777
# s3-hhdas      4.589689    33              F   0.276831           0.106871
# s2-const     10.487350    40              F  -0.125647           0.322421
# sr-nocars     5.087336    41              T  -5.914000           0.000000
# sr-carsltd    0.121748    42              F   0.017161           0.102197
# hov-const     0.544776    50              T -10.000000           0.000000
# bi-const      3.342154    60              T -10.000000           0.000000
# wk-ageo50     0.470743    73              F  -2.002936           0.465283
# wk-dintd      2.964029    76              T   0.000000           0.000000
# wk-hhcu5      6.443189    81              F   0.550408           0.200152
# wk-hh515      8.195197    82              F   0.553274           0.139720
# wk-hhdas      1.292153    83              F  -3.004883           0.930822
# Theta0099          inf   NaN            NaN        NaN                NaN
# Theta0999          NaN   999              F   0.541504           0.027348
#
#              t-stat_06
# coefficient
# timeutil     21.346726
# s3-const      3.096163
# s3-hhcu5     17.631663
# s3-hh515     12.683352
# s3-hhdas      2.590317
# s2-const      0.389700
# sr-nocars          inf
# sr-carsltd    0.167919
# hov-const          inf
# bi-const           inf
# wk-ageo50     4.304768
# wk-dintd           NaN
# wk-hhcu5      2.749954
# wk-hh515      3.959882
# wk-hhdas      3.228204
# Theta0099          NaN
# Theta0999    19.800243
