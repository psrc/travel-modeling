# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Compare Estimation Results, 2006 to 2014
# Set directory location for each

# %%
new_dir = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results\F12_archive'
old_dir = r'R:\SoundCast\releases\soundcast_release_c1\inputs\coefficients'

# %% [markdown]
# # Mode Tour Models

# %% [markdown]
# ## Work Tour Mode

# %%
new_fname = 'WorkTourModeModel.F12'
old_fname = 'WorkTourModeModel_psrcper1.F12'

df1 = load_f12(new_dir, new_fname)
df2 = load_f12(old_dir, old_fname)
# suffixes=

# Join old and new results
df = compare_df(df1,df2,suffixes=['_06','_14'])
# Out:
# Axes(0.125,0.125;0.775x0.775)
# ['t-stat_06', 't-stat_14']
# Axes(0.125,0.125;0.775x0.775)

# %% [markdown]
# ## School Tour Mode

# %%
new_fname = 'PayToParkAtWorkplaceModel.F12'
old_fname = 'PayToParkAtWorkplaceModel_psrcper1.F12'

df1 = load_f12(new_dir, new_fname)
df2 = load_f12(old_dir, old_fname)
# suffixes=

# Join old and new results
df = compare_df(df1,df2,suffixes=['_06','_14'])
# Out:
# Axes(0.125,0.125;0.775x0.775)
# ['t-stat_06', 't-stat_14']
# Axes(0.125,0.125;0.775x0.775)
