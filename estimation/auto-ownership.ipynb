# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Auto Ownership

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results\AutoOwnership'
dir_06 = r'R:\SoundCastDocuments\2006Estimation\personbased_estimationfiles\newer_coeff_outputs'

fname_14 = 'AutoOwnershipModel.F12'
fname_06 = 'AutoOwnershipModel_psrcper1.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)

# %%
# The 2006 version of this model needs reformatting 
    

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'],join_on='id')
# Out:
# Axes(0.125,0.125;0.775x0.775)
# ['t-stat_14', 't-stat_06']
# Axes(0.125,0.125;0.775x0.775)

# %% [markdown]
# ### Notes:
# -

# %%
df
# Out:
#     id coefficient_14 constrained_14  value_14  standard error_14  t-stat_14  \
# id
# 1    1     0v-1driver              F -1.722352           0.163703  10.521219
# 2    2     2v-1driver              F -4.212999           0.144346  29.186778
# 3    3     3v-1driver              F -4.451401           0.240230  18.529714
# 4    4     4v-idriver              F -4.159285           0.264823  15.705885
# 5    5     0v-2drivrs              T  0.000000           0.000000        NaN
# 6    6     1v-2drivrs              T  0.000000           0.000000        NaN
# 7    7     3v-2drivrs              T  0.000000           0.000000        NaN
# 8    8     4v-2drivrs              T  0.000000           0.000000        NaN
# 9    9     0v-3drivrs              F -0.507211           0.322366   1.573401
# 10  10     1v-3drivrs              F -1.244096           0.182421   6.819900
# 11  11     2v-3drivrs              F -1.982529           0.168905  11.737531
# ...
