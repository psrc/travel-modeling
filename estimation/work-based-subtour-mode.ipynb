# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Work-Based Subtour Mode
# ### Notes:
# - coefficient wt-const not used in 2014 model
# - bi-male (male & bike) was negative for 2014, with t-stat ~ 0.4; coefficient is somewhat small, could leave in, much higher t-stat in 2014
# - sr-drtowork had very small t-stat ~ 0.25, but sign is correct w/ small coefficient; could leave

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\with_transit_sub_mode\results\WorkBasedSubtourMode'
dir_06 = r'R:\SoundCast\releases\soundcast_release_c1\inputs\coefficients'

fname_14 = 'WorkBasedSubtourModeModel.F12'
fname_06 = 'WorkBasedSubtourModeModel_psrcper1.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# costutil        1    costutil              F  1.123734           0.303342
# timeutil        2    timeutil              F  0.861836           0.164742
# wt-const       20    wt-const              F -4.790535           0.980029
# s3-const       30    s3-const              F -4.713326           0.789657
# s2-const       40    s2-const              F -4.096503           0.771198
# da-const       50    da-const              F -3.480437           0.771735
# da-incu25      54   da-incu25              F  0.975106           0.897393
# da-inc2550     55  da-inc2550              F  0.146716           0.363619
# da-dtowork     58  da-dtowork              F  2.127597           0.590923
# da-stowork     59  da-stowork              F  1.749760           0.615868
# bi-const       60    bi-const              F -6.377605           1.039928
# bi-male        61     bi-male              F -0.402218           0.980381
# bi-btowork     69  bi-btowork              F  2.904438           1.000671
# wk-wtowork     79  wk-wtowork              T  5.000000           0.000000
# sr-dtowork     88  sr-dtowork              F  0.535433           0.402774
# sr-stowork     89  sr-stowork              F  1.182621           0.541700
# modenest       99    modenest              F  0.889593           0.177685
#
#              t-stat_14 id_06 constrained_06   value_06  standard error_06  \
# coefficient
# costutil      3.704511     1              F   1.466865           0.620305
# timeutil      5.231414     2              F   4.576391           1.867374
# wt-const      4.888159    20              F  -3.632044           1.527329
# s3-const      5.968824    30              F  -5.585282           2.007231
# s2-const      5.311870    40              F  -5.168120           1.937207
# da-const      4.509888    50              F  -3.937186           1.696752
# da-incu25     1.086599    54              F   0.329088           1.056828
# da-inc2550    0.403490    55              T   0.000000           0.000000
# da-dtowork    3.600465    58              F   2.825499           1.263583
# da-stowork    2.841128    59              F   1.910907           1.036034
# bi-const      6.132738    60              F -22.662014        1230.718897
# bi-male       0.410267    61              F  14.429452        1230.715112
# bi-btowork    2.902490    69              T   4.253500           0.000000
# wk-wtowork         inf    79              T   5.000000           0.000000
# sr-dtowork    1.329362    88              F   0.793378           0.629956
# sr-stowork    2.183165    89              F   1.619925           0.948820
# modenest      5.006570    99              F   0.722657           0.291876
#
#              t-stat_06
# coefficient
# costutil      2.364748
# timeutil      2.450710
# wt-const      2.378036
# s3-const      2.782581
# s2-const      2.667820
# da-const      2.320424
# da-incu25     0.311392
# da-inc2550         NaN
# da-dtowork    2.236101
# da-stowork    1.844443
# bi-const      0.018414
# bi-male       0.011724
# bi-btowork         inf
# wk-wtowork         inf
# sr-dtowork    1.259419
# sr-stowork    1.707304
# modenest      2.475902
