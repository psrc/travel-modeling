# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Work-Based Subtour Mode

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results\WorkBasedSubtourModeModel'
dir_06 = r'R:\SoundCast\releases\soundcast_release_c1\inputs\coefficients'

fname_14 = 'WorkBasedSubtourModeModel.F12'
fname_06 = 'WorkBasedSubtourModeModel_psrcper1.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])
# Out:
# Axes(0.125,0.125;0.775x0.775)
# ['t-stat_14', 't-stat_06']
# Axes(0.125,0.125;0.775x0.775)

# %% [markdown]
# ### Notes:
# - coefficient wt-const not used in 2014 model
# - bi-male (male & bike) was negative for 2014, with t-stat ~ 0.4; coefficient is somewhat small, could leave in
# - sr-drtowork had very small t-stat ~ 0.25, but sign is correct w/ small coefficient; could leave

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# costutil        1    costutil              F  1.824525           0.585903
# timeutil        2    timeutil              F  0.502369           0.143676
# s3-const       30    s3-const              F -3.550166           0.798596
# s2-const       40    s2-const              F -2.627187           0.720205
# da-const       50    da-const              F -1.704637           0.634741
# da-incu25      54   da-incu25              F  3.030204           1.816545
# da-inc2550     55  da-inc2550              F  0.626559           0.445277
# da-dtowork     58  da-dtowork              F  2.124811           0.769168
# da-stowork     59  da-stowork              F  1.952322           0.797360
# bi-const       60    bi-const              F -6.979545           1.832131
# bi-male        61     bi-male              F -0.387500           1.161353
# bi-btowork     69  bi-btowork              F  4.774383           1.793666
# wk-wtowork     79  wk-wtowork              F  2.116168           1.543236
# sr-dtowork     88  sr-dtowork              F  0.063137           0.440600
# sr-stowork     89  sr-stowork              F  1.210746           0.661144
# modenest       99    modenest              F  0.745180           0.220061
# wt-const      NaN    wt-const            NaN       NaN                NaN
#
#              t-stat_14 id_06 constrained_06   value_06  standard error_06  \
# coefficient
# costutil      3.114041     1              F   1.466865           0.620305
# timeutil      3.496534     2              F   4.576391           1.867374
# s3-const      4.445509    30              F  -5.585282           2.007231
# s2-const      3.647833    40              F  -5.168120           1.937207
# da-const      2.685564    50              F  -3.937186           1.696752
# da-incu25     1.668114    54              F   0.329088           1.056828
# da-inc2550    1.407120    55              T   0.000000           0.000000
# da-dtowork    2.762480    58              F   2.825499           1.263583
# da-stowork    2.448482    59              F   1.910907           1.036034
# bi-const      3.809522    60              F -22.662014        1230.718897
# bi-male       0.333663    61              F  14.429452        1230.715112
# bi-btowork    2.661802    69              T   4.253500           0.000000
# wk-wtowork    1.371253    79              T   5.000000           0.000000
# sr-dtowork    0.143297    88              F   0.793378           0.629956
# sr-stowork    1.831288    89              F   1.619925           0.948820
# modenest      3.386243    99              F   0.722657           0.291876
# wt-const           NaN    20              F  -3.632044           1.527329
#
#              t-stat_06
# coefficient
# costutil      2.364748
# timeutil      2.450710
# s3-const      2.782581
# s2-const      2.667820
# da-const      2.320424
# da-incu25     0.311392
# da-inc2550         NaN
# da-dtowork    2.236101
# da-stowork    1.844443
# bi-const      0.018414
# bi-male       0.011724
# bi-btowork         inf
# wk-wtowork         inf
# sr-dtowork    1.259419
# sr-stowork    1.707304
# modenest      2.475902
# wt-const      2.378036
