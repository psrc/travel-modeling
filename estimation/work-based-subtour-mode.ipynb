# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Work-Based Subtour Mode

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results\WorkBasedSubtourModeModel'
dir_06 = r'R:\SoundCast\releases\soundcast_release_c1\inputs\coefficients'

fname_14 = 'WorkBasedSubtourModeModel.F12'
fname_06 = 'WorkBasedSubtourModeModel_psrcper1.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])
# Out:
# Axes(0.125,0.125;0.775x0.775)
# ['t-stat_14', 't-stat_06']
# Axes(0.125,0.125;0.775x0.775)

# %% [markdown]
# ### Notes:
# - coefficient wt-const not used in 2014 model
# - bi-male (male & bike) was negative for 2014, with t-stat ~ 0.4; coefficient is somewhat small, could leave in, much higher t-stat in 2014
# - sr-drtowork had very small t-stat ~ 0.25, but sign is correct w/ small coefficient; could leave

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# costutil        1    costutil              F  1.123335           0.301358
# timeutil        2    timeutil              F  0.850825           0.161808
# wt-const       20    wt-const              F -4.617491           0.945145
# s3-const       30    s3-const              F -4.678185           0.778855
# s2-const       40    s2-const              F -4.061109           0.760529
# da-const       50    da-const              F -3.443569           0.760828
# da-incu25      54   da-incu25              F  0.967459           0.891359
# da-inc2550     55  da-inc2550              F  0.145578           0.361183
# da-dtowork     58  da-dtowork              F  2.111264           0.584807
# da-stowork     59  da-stowork              F  1.734290           0.610099
# bi-const       60    bi-const              F -6.348676           1.033498
# ...
