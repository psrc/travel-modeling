# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Other Home-Based Tour Mode

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results\OtherHomeBasedMode\estimated_district_constants'
dir_06 = r'R:\SoundCast\releases\soundcast_release_c1\inputs\coefficients'

fname_14 = 'OtherHomeBasedTourModeModel.F12'
fname_06 = 'OtherHomeBasedTourModeModel_psrcper1.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])
# Out:
# Axes(0.125,0.125;0.775x0.775)
# ['t-stat_14', 't-stat_06']
# Axes(0.125,0.125;0.775x0.775)

# %% [markdown]
# ### Notes:
# - added district constants in 2014

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# costutil        1    costutil              F  0.454471           0.074916
# timeutil        2    timeutil              F  0.649661           0.035450
# wt-const       20    wt-const              F -2.314082           0.380720
# wt-nocars      21   wt-nocars              F  1.539101           0.185530
# s3-const       30    s3-const              F -1.721000           0.158863
# sr-hhcu5       31    sr-hhcu5              F  0.507850           0.082656
# sr-hh515       32    sr-hh515              F  0.221321           0.064923
# sr-hhnwa       34    sr-hhnwa              F  0.115222           0.045703
# sr-lndist      35   sr-lndist              F  0.148858           0.033880
# s3-onephh      38   s3-onephh              F -2.801774           0.183470
# s3-twophh      39   s3-twophh              F -2.816777           0.130722
# s2-const       40    s2-const              F -1.951012           0.158462
# sr-nocars      41   sr-nocars              F -1.553282           0.211154
# sr-carsltw     43  sr-carsltw              F -0.080530           0.138028
# s2-onephh      48   s2-onephh              F -1.442193           0.134733
# da-const       50    da-const              F -0.407456           0.114018
# da-carsltd     52  da-carsltd              F -0.787990           0.091895
# inc0to25k      54   inc0to25k              F  0.000400           0.124344
# bi-const       60    bi-const              F -4.429491           0.360650
# bi-male        61     bi-male              F  0.618202           0.197268
# bi-ageo50      63   bi-ageo50              F -0.864823           0.251496
# wk-ageo50      73   wk-ageo50              F -0.058912           0.092809
# tr-shop       120     tr-shop              F -0.477147           0.165117
# tr-omixed     124   tr-omixed              F  0.293996           0.349308
# tr-dempdn     128   tr-dempdn              F  0.000036           0.000006
# da-escsptr    131  da-escsptr              T  0.000000           0.000000
# da-othsptr    132  da-othsptr              F  0.211919           0.050331
# sr-escsptr    133  sr-escsptr              T  0.000000           0.000000
# sr-othsptr    134  sr-othsptr              F  0.300306           0.051621
# sr-shop       136     sr-shop              F -0.044740           0.092698
# sr-meal       137     sr-meal              F  1.324616           0.138971
# sr-socrec     138   sr-socrec              F  0.468368           0.092071
# bi-socrec     160   bi-socrec              F  1.598281           0.213873
# bi-class1     161   bi-class1              T  0.000000           0.000000
# bi-class2     162   bi-class2              T  0.000000           0.000000
# bi-gauntl     163   bi-gauntl              T  0.000000           0.000000
# bi-omixed     164   bi-omixed              F  0.115129           0.445800
# bi-ohhddn     165   bi-ohhddn              F  0.000237           0.000077
# bi-dempdn     168   bi-dempdn              F -0.000002           0.000013
# bi-dmixed     169   bi-dmixed              T  0.000000           0.000000
# wk-meal       171     wk-meal              F  1.098205           0.157513
# wk-socrec     172   wk-socrec              F  2.100889           0.143831
# wk-ohhddn     175   wk-ohhddn              F  0.000153           0.000050
# wk-dempdn     178   wk-dempdn              F  0.000013           0.000047
# distcont1     201   distcont1              F -2.329704           0.915578
# distcont2     202   distcont2              F -0.354706           0.347926
# distcont3     203   distcont3              F -0.665403           0.198048
# distcont4     204   distcont4              T  0.000000           0.000000
# distcont5     205   distcont5              F  0.093263           0.277233
# distcont6     206   distcont6              F -0.158951           0.279217
# distcont7     207   distcont7              F -0.302182           0.361124
# distcont8     208   distcont8              F -0.339829           0.365812
# distcont9     209   distcont9              F  0.029037           0.426084
# distcon10     210   distcon10              F -0.889836           0.522155
# distcon11     211   distcon11              T -4.000000           0.000000
# modenest       99    modenest              F  0.872471           0.046039
#
#              t-stat_14 id_06 constrained_06  value_06  standard error_06  \
# coefficient
# costutil      6.066392     1              F  1.300000           0.075525
# timeutil     18.325949     2              F  2.249104           0.119837
# wt-const      6.078175    20              F -2.400000           0.258114
# wt-nocars     8.295690    21              F  5.000000           0.460440
# s3-const     10.833235    30              F -1.700000           0.177136
# sr-hhcu5      6.144131    31              F  0.590277           0.085947
# sr-hh515      3.408990    32              F  0.350828           0.052095
# sr-hhnwa      2.521093    34              F  0.184890           0.039908
# sr-lndist     4.393695    35              F  0.207327           0.033263
# s3-onephh    15.270979    38              F -2.866452           0.178040
# s3-twophh    21.547880    39              F -2.093647           0.083155
# s2-const     12.312208    40              F -1.400000           0.176242
# sr-nocars     7.356174    41              F -0.527237           0.352617
# sr-carsltw    0.583434    43              F -0.730377           0.204598
# s2-onephh    10.704085    48              F -1.524320           0.143971
# da-const      3.573608    50              F  1.306556           0.163325
# da-carsltd    8.574923    52              F -0.751612           0.097353
# inc0to25k     0.003214    54              F -0.178646           0.150273
# bi-const     12.281984    60              F -3.400000           0.332602
# bi-male       3.133823    61              F  0.079401           0.251488
# bi-ageo50     3.438721    63              F -1.342739           0.279258
# wk-ageo50     0.634764    73              F -0.291360           0.111605
# tr-shop       2.889751   120              F -0.512843           0.357858
# tr-omixed     0.841652   124              T  0.400000           0.000000
# tr-dempdn     5.980467   128              F  0.000001           0.000007
# da-escsptr         NaN   131              T  0.000000           0.000000
# da-othsptr    4.210539   132              F -0.064949           0.035233
# sr-escsptr         NaN   133              F  0.546361           0.198634
# sr-othsptr    5.817557   134              F -0.052847           0.037108
# sr-shop       0.482639   136              F  0.297854           0.092238
# sr-meal       9.531603   137              F  1.985240           0.157508
# sr-socrec     5.087045   138              F  0.799961           0.087769
# bi-socrec     7.473022   160              F  0.456163           0.246479
# bi-class1          NaN   161              T  0.000000           0.000000
# bi-class2          NaN   162              T  0.000000           0.000000
# bi-gauntl          NaN   163              T  0.000000           0.000000
# bi-omixed     0.258252   164              T  0.000000           0.000000
# bi-ohhddn     3.069202   165              F  0.000001           0.000103
# bi-dempdn     0.187137   168              F  0.000000           0.000015
# bi-dmixed          NaN   169              T  0.000000           0.000000
# wk-meal       6.972169   171              F  2.700000           0.200552
# wk-socrec    14.606643   172              F  2.700000           0.151602
# wk-ohhddn     3.095415   175              F  0.000001           0.000063
# wk-dempdn     0.272870   178              F  0.000001           0.000055
# distcont1     2.544516   NaN            NaN       NaN                NaN
# distcont2     1.019486   NaN            NaN       NaN                NaN
# distcont3     3.359802   NaN            NaN       NaN                NaN
# distcont4          NaN   NaN            NaN       NaN                NaN
# distcont5     0.336407   NaN            NaN       NaN                NaN
# distcont6     0.569273   NaN            NaN       NaN                NaN
# distcont7     0.836783   NaN            NaN       NaN                NaN
# distcont8     0.928971   NaN            NaN       NaN                NaN
# distcont9     0.068148   NaN            NaN       NaN                NaN
# distcon10     1.704161   NaN            NaN       NaN                NaN
# distcon11          inf   NaN            NaN       NaN                NaN
# modenest     18.950655    99              F  0.803146           0.046538
#
#              t-stat_06
# coefficient
# costutil     17.212871
# timeutil     18.767960
# wt-const      9.298221
# wt-nocars    10.859184
# s3-const      9.597162
# sr-hhcu5      6.867954
# sr-hh515      6.734452
# sr-hhnwa      4.632966
# sr-lndist     6.233017
# s3-onephh    16.100061
# s3-twophh    25.177539
# s2-const      7.943601
# sr-nocars     1.495211
# sr-carsltw    3.569822
# s2-onephh    10.587677
# da-const      7.999735
# da-carsltd    7.720489
# inc0to25k     1.188815
# bi-const     10.222434
# bi-male       0.315727
# bi-ageo50     4.808233
# wk-ageo50     2.610631
# tr-shop       1.433091
# tr-omixed          inf
# tr-dempdn     0.129896
# da-escsptr         NaN
# da-othsptr    1.843426
# sr-escsptr    2.750587
# sr-othsptr    1.424145
# sr-shop       3.229195
# sr-meal      12.604021
# sr-socrec     9.114409
# bi-socrec     1.850715
# bi-class1          NaN
# bi-class2          NaN
# bi-gauntl          NaN
# bi-omixed          NaN
# bi-ohhddn     0.008169
# bi-dempdn     0.027026
# bi-dmixed          NaN
# wk-meal      13.462816
# wk-socrec    17.809816
# wk-ohhddn     0.015823
# wk-dempdn     0.016506
# distcont1          NaN
# distcont2          NaN
# distcont3          NaN
# distcont4          NaN
# distcont5          NaN
# distcont6          NaN
# distcont7          NaN
# distcont8          NaN
# distcont9          NaN
# distcon10          NaN
# distcon11          NaN
# modenest     17.257757
