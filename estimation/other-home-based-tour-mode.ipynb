# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Other Home-Based Tour Mode

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results\OtherHomeBasedMode\estimated_district_constants'
dir_06 = r'R:\SoundCast\releases\soundcast_release_c1\inputs\coefficients'

fname_14 = 'OtherHomeBasedTourModeModel.F12'
fname_06 = 'OtherHomeBasedTourModeModel_psrcper1.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])
# Out:
# Axes(0.125,0.125;0.775x0.775)
# ['t-stat_14', 't-stat_06']
# Axes(0.125,0.125;0.775x0.775)

# %% [markdown]
# ### Notes:
# - added district constants in 2014
# - sign change in:
#     - sr-shop (from + to - in 2014, higher t-stat in 2014)
#     - sr-escsptr (from - to + in 2014, constrained in 2014)
#     - da-othsptr (from - to + in 2014, lower t-stat in 2014)
#     - da-const
# - transit density variable (tr-dempdn) t-stat much higher in 2014
# - tr-omixed valid in 2014
# - inc0to25k constrained in 2014

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# costutil        1    costutil              F  0.454343           0.074899
# timeutil        2    timeutil              F  0.650560           0.035494
# wt-const       20    wt-const              F -2.467153           0.383322
# wt-nocars      21   wt-nocars              F  1.549652           0.186035
# s3-const       30    s3-const              F -1.724684           0.159019
# sr-hhcu5       31    sr-hhcu5              F  0.508826           0.082725
# sr-hh515       32    sr-hh515              F  0.221476           0.064970
# sr-hhnwa       34    sr-hhnwa              F  0.115214           0.045724
# sr-lndist      35   sr-lndist              F  0.151127           0.033918
# s3-onephh      38   s3-onephh              F -2.800621           0.183446
# s3-twophh      39   s3-twophh              F -2.816780           0.130723
# s2-const       40    s2-const              F -1.954678           0.158618
# sr-nocars      41   sr-nocars              F -1.538627           0.210655
# sr-carsltw     43  sr-carsltw              F -0.078940           0.138051
# s2-onephh      48   s2-onephh              F -1.441079           0.134708
# da-const       50    da-const              F -0.406971           0.114067
# da-carsltd     52  da-carsltd              F -0.788903           0.091929
# inc0to25k      54   inc0to25k              F  0.000570           0.124379
# bi-const       60    bi-const              F -4.429471           0.360709
# bi-male        61     bi-male              F  0.617391           0.197278
# bi-ageo50      63   bi-ageo50              F -0.863719           0.251537
# wk-ageo50      73   wk-ageo50              F -0.058533           0.092890
# tr-shop       120     tr-shop              F -0.466545           0.165187
# tr-omixed     124   tr-omixed              F  0.285071           0.349394
# tr-dempdn     128   tr-dempdn              F  0.000036           0.000006
# da-escsptr    131  da-escsptr              T  0.000000           0.000000
# da-othsptr    132  da-othsptr              F  0.212601           0.050324
# sr-escsptr    133  sr-escsptr              T  0.000000           0.000000
# sr-othsptr    134  sr-othsptr              F  0.300779           0.051611
# sr-shop       136     sr-shop              F -0.045662           0.092737
# sr-meal       137     sr-meal              F  1.323175           0.138970
# sr-socrec     138   sr-socrec              F  0.467619           0.092096
# bi-socrec     160   bi-socrec              F  1.598609           0.213899
# bi-class1     161   bi-class1              T  0.000000           0.000000
# bi-class2     162   bi-class2              T  0.000000           0.000000
# bi-gauntl     163   bi-gauntl              T  0.000000           0.000000
# bi-omixed     164   bi-omixed              F  0.115266           0.445849
# bi-ohhddn     165   bi-ohhddn              F  0.000237           0.000077
# bi-dempdn     168   bi-dempdn              F -0.000003           0.000013
# bi-dmixed     169   bi-dmixed              T  0.000000           0.000000
# wk-meal       171     wk-meal              F  1.097382           0.157588
# wk-socrec     172   wk-socrec              F  2.102212           0.143918
# wk-ohhddn     175   wk-ohhddn              F  0.000153           0.000050
# wk-dempdn     178   wk-dempdn              F  0.000012           0.000047
# distcont1     201   distcont1              F -2.359733           0.926292
# distcont2     202   distcont2              F -0.359816           0.347704
# distcont3     203   distcont3              F -0.664088           0.198110
# distcont4     204   distcont4              T  0.000000           0.000000
# distcont5     205   distcont5              F  0.076362           0.277356
# distcont6     206   distcont6              F -0.173927           0.279436
# distcont7     207   distcont7              F -0.317623           0.361168
# distcont8     208   distcont8              F -0.341358           0.366232
# distcont9     209   distcont9              F  0.019855           0.427415
# distcon10     210   distcon10              F -0.917906           0.523495
# distcon11     211   distcon11              T -4.000000           0.000000
# modenest       99    modenest              F  0.872079           0.046014
#
#              t-stat_14 id_06 constrained_06  value_06  standard error_06  \
# coefficient
# costutil      6.066087     1              F  1.300000           0.075525
# timeutil     18.328928     2              F  2.249104           0.119837
# wt-const      6.436244    20              F -2.400000           0.258114
# wt-nocars     8.329904    21              F  5.000000           0.460440
# s3-const     10.845804    30              F -1.700000           0.177136
# sr-hhcu5      6.150812    31              F  0.590277           0.085947
# sr-hh515      3.408899    32              F  0.350828           0.052095
# sr-hhnwa      2.519794    34              F  0.184890           0.039908
# sr-lndist     4.455683    35              F  0.207327           0.033263
# s3-onephh    15.266766    38              F -2.866452           0.178040
# s3-twophh    21.547693    39              F -2.093647           0.083155
# s2-const     12.323151    40              F -1.400000           0.176242
# sr-nocars     7.303999    41              F -0.527237           0.352617
# sr-carsltw    0.571817    43              F -0.730377           0.204598
# s2-onephh    10.697761    48              F -1.524320           0.143971
# da-const      3.567822    50              F  1.306556           0.163325
# da-carsltd    8.581612    52              F -0.751612           0.097353
# inc0to25k     0.004583    54              F -0.178646           0.150273
# bi-const     12.279906    60              F -3.400000           0.332602
# bi-male       3.129539    61              F  0.079401           0.251488
# bi-ageo50     3.433762    63              F -1.342739           0.279258
# wk-ageo50     0.630135    73              F -0.291360           0.111605
# tr-shop       2.824354   120              F -0.512843           0.357858
# tr-omixed     0.815901   124              T  0.400000           0.000000
# tr-dempdn     6.002318   128              F  0.000001           0.000007
# da-escsptr         NaN   131              T  0.000000           0.000000
# da-othsptr    4.224621   132              F -0.064949           0.035233
# sr-escsptr         NaN   133              F  0.546361           0.198634
# sr-othsptr    5.827838   134              F -0.052847           0.037108
# sr-shop       0.492385   136              F  0.297854           0.092238
# sr-meal       9.521270   137              F  1.985240           0.157508
# sr-socrec     5.077497   138              F  0.799961           0.087769
# bi-socrec     7.473677   160              F  0.456163           0.246479
# bi-class1          NaN   161              T  0.000000           0.000000
# bi-class2          NaN   162              T  0.000000           0.000000
# bi-gauntl          NaN   163              T  0.000000           0.000000
# bi-omixed     0.258531   164              T  0.000000           0.000000
# bi-ohhddn     3.072529   165              F  0.000001           0.000103
# bi-dempdn     0.193276   168              F  0.000000           0.000015
# bi-dmixed          NaN   169              T  0.000000           0.000000
# wk-meal       6.963592   171              F  2.700000           0.200552
# wk-socrec    14.607061   172              F  2.700000           0.151602
# wk-ohhddn     3.092961   175              F  0.000001           0.000063
# wk-dempdn     0.267009   178              F  0.000001           0.000055
# distcont1     2.547503   NaN            NaN       NaN                NaN
# distcont2     1.034834   NaN            NaN       NaN                NaN
# distcont3     3.352112   NaN            NaN       NaN                NaN
# distcont4          NaN   NaN            NaN       NaN                NaN
# distcont5     0.275321   NaN            NaN       NaN                NaN
# distcont6     0.622422   NaN            NaN       NaN                NaN
# distcont7     0.879433   NaN            NaN       NaN                NaN
# distcont8     0.932080   NaN            NaN       NaN                NaN
# distcont9     0.046454   NaN            NaN       NaN                NaN
# distcon10     1.753418   NaN            NaN       NaN                NaN
# distcon11          inf   NaN            NaN       NaN                NaN
# modenest     18.952286    99              F  0.803146           0.046538
#
#              t-stat_06
# coefficient
# costutil     17.212871
# timeutil     18.767960
# wt-const      9.298221
# wt-nocars    10.859184
# s3-const      9.597162
# sr-hhcu5      6.867954
# sr-hh515      6.734452
# sr-hhnwa      4.632966
# sr-lndist     6.233017
# s3-onephh    16.100061
# s3-twophh    25.177539
# s2-const      7.943601
# sr-nocars     1.495211
# sr-carsltw    3.569822
# s2-onephh    10.587677
# da-const      7.999735
# da-carsltd    7.720489
# inc0to25k     1.188815
# bi-const     10.222434
# bi-male       0.315727
# bi-ageo50     4.808233
# wk-ageo50     2.610631
# tr-shop       1.433091
# tr-omixed          inf
# tr-dempdn     0.129896
# da-escsptr         NaN
# da-othsptr    1.843426
# sr-escsptr    2.750587
# sr-othsptr    1.424145
# sr-shop       3.229195
# sr-meal      12.604021
# sr-socrec     9.114409
# bi-socrec     1.850715
# bi-class1          NaN
# bi-class2          NaN
# bi-gauntl          NaN
# bi-omixed          NaN
# bi-ohhddn     0.008169
# bi-dempdn     0.027026
# bi-dmixed          NaN
# wk-meal      13.462816
# wk-socrec    17.809816
# wk-ohhddn     0.015823
# wk-dempdn     0.016506
# distcont1          NaN
# distcont2          NaN
# distcont3          NaN
# distcont4          NaN
# distcont5          NaN
# distcont6          NaN
# distcont7          NaN
# distcont8          NaN
# distcont9          NaN
# distcon10          NaN
# distcon11          NaN
# modenest     17.257757
