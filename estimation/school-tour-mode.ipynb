# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Compare Estimation Results, 2006 to 2014
# Set directory location for each

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results\SchoolTourModeModel'
dir_06 = r'R:\SoundCastDocuments\2006Estimation\personbased_estimationfiles\newer_coeff_outputs'
# dir_14_old = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results_archive\withoutNodeToNodeDistances\WorkTourMode'

# %% [markdown]
# # School Tour Mode

# %%
fname_14 = r'SchoolTourModeModel.F12'
fname_06 = 'SchoolTourModeModel_psrcper1.F12'
# fname_14_old = 'WorkTourModeModel_psrcper1.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)
# df_14_old = load_f12(dir_14_old, fname_14_old)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])
# Out:
# Axes(0.125,0.125;0.775x0.775)
# ['t-stat_14', 't-stat_06']
# Axes(0.125,0.125;0.775x0.775)

# %% [markdown]
# ### Notes:
# - Drive alone low-income (da-incu25) reversed signs. + in 2014 estimation, suggesting low income households are more likely to drive alone. The t-stat is slightly higher in 2014 than in 2006, at 2.2 vs. 2.1, so the variable is kept. The sign could make sense as some low-income workers can only afford to live in areas far-out from the city and need cars to get around. Gas is also cheaper now, reducing costs of driving relative to 2006 (?)
# - stronger 2014 t-stats on variables related to land use (e.g., bi-omixed, bi-dmixed, tr-dintdn, tr-ointdn)

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# costutil        1    costutil              T    0.7000                NaN
# timeutil        2    timeutil              F    1.8914                NaN
# sb-const       10    sb-const              F   -0.4315                NaN
# sb-chun5       17    sb-chun5              F   -5.7475                NaN
# sb-univtr      18   sb-univtr              T   -5.0000                NaN
# s3-const       30    s3-const              F   -0.2479                NaN
# s3-twophh      37   s3-twophh              F   -1.4425                NaN
# s2-onephh      38   s2-onephh              F   -0.2573                NaN
# s2-const       40    s2-const              F   -1.0000                NaN
# sr-nocars      41   sr-nocars              T   -5.0000                NaN
# sr-incu25      44   sr-incu25              F   -1.9369                NaN
# sr-inc2550     45  sr-inc2550              F   -1.0349                NaN
# sr-chun5       47    sr-chun5              F    1.8222                NaN
# da-const       50    da-const              F    0.9844                NaN
# da-carsltd     52  da-carsltd              F   -2.3506                NaN
# da-incu25      54   da-incu25              F   -0.2968                NaN
# da-inco75      56   da-inco75              F    0.5557                NaN
# da-ch1617      59   da-ch1617              F   -1.0634                NaN
# bi-const       60    bi-const              F   -4.0000                NaN
# bi-male        61     bi-male              F    0.6896                NaN
# bi-univtr      69   bi-univtr              F    0.4382                NaN
# wk-univtr      79   wk-univtr              F    0.3094                NaN
# da-escsptr    131  da-escsptr              F   -6.8486                NaN
# da-othsptr    132  da-othsptr              F    0.2032                NaN
# sr-escsptr    133  sr-escsptr              F    1.1595                NaN
# sr-othsptr    134  sr-othsptr              F   -0.1292                NaN
# bi-class1     161   bi-class1              T    0.0000                NaN
# bi-class2     162   bi-class2              T    0.0000                NaN
# bi-gauntl     163   bi-gauntl              T    0.0000                NaN
# bi-omixed     164   bi-omixed              F    0.0051                NaN
# bi-dempdn     168   bi-dempdn              T    0.0000                NaN
# bi-dmixed     169   bi-dmixed              T    0.0000                NaN
# wk-dmixed     179   wk-dmixed              T    0.5000                NaN
# modenest       99    modenest              F    0.7030                NaN
# wt-const      NaN    wt-const            NaN       NaN                NaN
# wt-nocars     NaN   wt-nocars            NaN       NaN                NaN
# wt-carsltd    NaN  wt-carsltd            NaN       NaN                NaN
# wt-chun5      NaN    wt-chun5            NaN       NaN                NaN
# wt-univtr     NaN   wt-univtr            NaN       NaN                NaN
# wt-ch1617     NaN   wt-ch1617            NaN       NaN                NaN
# tr-ologts     NaN   tr-ologts            NaN       NaN                NaN
# tr-dmixed     NaN   tr-dmixed            NaN       NaN                NaN
#
#              t-stat_14 id_06 constrained_06  value_06  standard error_06  \
# coefficient
# costutil           NaN     1              T  0.082700           0.000000
# timeutil           NaN     2              F  1.791423           0.183030
# sb-const           NaN    10              F -0.331495           0.163272
# sb-chun5           NaN    17              F -5.747538           1.189221
# sb-univtr          NaN    18              T -5.000000           0.000000
# s3-const           NaN    30              F -0.444789           0.169423
# s3-twophh          NaN    37              F -1.442521           0.306650
# s2-onephh          NaN    38              F -0.257307           1.234620
# s2-const           NaN    40              F -1.308962           0.172233
# sr-nocars          NaN    41              T -5.000000           0.000000
# sr-incu25          NaN    44              F -1.936874           0.460599
# sr-inc2550         NaN    45              F -1.034853           0.199275
# sr-chun5           NaN    47              F  1.822244           0.440307
# da-const           NaN    50              F  2.284389           0.424713
# da-carsltd         NaN    52              F -2.350552           0.350737
# da-incu25          NaN    54              F -0.296835           0.658368
# da-inco75          NaN    56              F  0.555739           0.274603
# da-ch1617          NaN    59              F -2.063363           0.379634
# bi-const           NaN    60              F -3.987930           0.506654
# bi-male            NaN    61              F  0.689615           0.366698
# bi-univtr          NaN    69              F  1.338162           0.802128
# wk-univtr          NaN    79              F  0.479433           0.747899
# da-escsptr         NaN   131              F -6.848638           1.849374
# da-othsptr         NaN   132              F  0.203248           0.151188
# sr-escsptr         NaN   133              F  1.159536           0.295395
# sr-othsptr         NaN   134              F -0.129245           0.071962
# bi-class1          NaN   161              T  0.000000           0.000000
# bi-class2          NaN   162              T  0.000000           0.000000
# bi-gauntl          NaN   163              T  0.000000           0.000000
# bi-omixed          NaN   164              F  0.005052           0.768240
# bi-dempdn          NaN   168              T  0.000000           0.000000
# bi-dmixed          NaN   169              T  0.000000           0.000000
# wk-dmixed          NaN   179              T  0.000000           0.000000
# modenest           NaN    99              F  0.703002           0.064360
# wt-const           NaN    20              F -0.770936           0.587217
# wt-nocars          NaN    21              F  3.416576           0.924748
# wt-carsltd         NaN    22              F  2.023100           0.395436
# wt-chun5           NaN    27              T -5.000000           0.000000
# wt-univtr          NaN    28              F  3.432831           0.529108
# wt-ch1617          NaN    29              F -0.370225           0.458007
# tr-ologts          NaN   122              F -0.174182           0.181952
# tr-dmixed          NaN   129              T  0.000000           0.000000
#
#              t-stat_06
# coefficient
# costutil           inf
# timeutil      9.787599
# sb-const      2.030330
# sb-chun5      4.833026
# sb-univtr          inf
# s3-const      2.625323
# s3-twophh     4.704134
# s2-onephh     0.208410
# s2-const      7.599940
# sr-nocars          inf
# sr-incu25     4.205124
# sr-inc2550    5.193093
# sr-chun5      4.138576
# da-const      5.378661
# da-carsltd    6.701750
# da-incu25     0.450865
# da-inco75     2.023788
# da-ch1617     5.435137
# bi-const      7.871104
# bi-male       1.880606
# bi-univtr     1.668265
# wk-univtr     0.641040
# da-escsptr    3.703219
# da-othsptr    1.344342
# sr-escsptr    3.925370
# sr-othsptr    1.796012
# bi-class1          NaN
# bi-class2          NaN
# bi-gauntl          NaN
# bi-omixed     0.006576
# bi-dempdn          NaN
# bi-dmixed          NaN
# wk-dmixed          NaN
# modenest     10.922949
# wt-const      1.312864
# wt-nocars     3.694604
# wt-carsltd    5.116132
# wt-chun5           inf
# wt-univtr     6.487964
# wt-ch1617     0.808339
# tr-ologts     0.957296
# tr-dmixed          NaN
