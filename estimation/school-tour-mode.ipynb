# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Compare Estimation Results, 2006 to 2014
# Set directory location for each

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\with_transit_sub_mode\results\SchoolTourMode'
dir_06 = r'R:\SoundCastDocuments\2006Estimation\personbased_estimationfiles\newer_coeff_outputs'
# dir_14_old = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results_archive\withoutNodeToNodeDistances\WorkTourMode'

# %% [markdown]
# # School Tour Mode

# %%
fname_14 = r'SchoolTourModeModel.F12'
fname_06 = 'SchoolTourModeModel_psrcper1.F12'
# fname_14_old = 'WorkTourModeModel_psrcper1.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)
# df_14_old = load_f12(dir_14_old, fname_14_old)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])

# %% [markdown]
# ### Notes:
# - Drive alone low-income (da-incu25) reversed signs. + in 2014 estimation, suggesting low income households are more likely to drive alone. The t-stat is slightly higher in 2014 than in 2006, at 2.2 vs. 2.1, so the variable is kept. The sign could make sense as some low-income workers can only afford to live in areas far-out from the city and need cars to get around. Gas is also cheaper now, reducing costs of driving relative to 2006 (?)
# - stronger 2014 t-stats on variables related to land use (e.g., bi-omixed, bi-dmixed, tr-dintdn, tr-ointdn)

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# costutil        1    costutil              F  1.616246           0.194674
# timeutil        2    timeutil              F  0.894041           0.082545
# sb-const       10    sb-const              F -0.355111           0.343088
# sb-chun5       17    sb-chun5              T -5.747500           0.000000
# sb-univtr      18   sb-univtr              F -5.248798           0.684399
# wt-const       20    wt-const              F -3.805433           0.919288
# wt-nocars      21   wt-nocars              F -0.090155           0.174767
# wt-carsltd     22  wt-carsltd              F -0.015103           0.301542
# wt-chun5       27    wt-chun5              T -5.000000           0.000000
# wt-univtr      28   wt-univtr              F  5.285383           0.933498
# wt-ch1617      29   wt-ch1617              F  3.206675           0.845175
# s3-const       30    s3-const              F -0.451328           0.342998
# s3-twophh      37   s3-twophh              F -2.094162           0.316381
# s2-onephh      38   s2-onephh              F -1.019171           0.333494
# s2-const       40    s2-const              F -0.903105           0.345002
# sr-nocars      41   sr-nocars              F -1.351890           0.338225
# sr-incu25      44   sr-incu25              F  0.225161           0.290746
# sr-inc2550     45  sr-inc2550              F -0.532565           0.270962
# sr-chun5       47    sr-chun5              F  1.561864           0.536116
# da-const       50    da-const              F  2.196405           0.502408
# da-carsltd     52  da-carsltd              F -2.157502           0.363244
# da-incu25      54   da-incu25              T  0.000000           0.000000
# da-inco75      56   da-inco75              F  0.308602           0.304880
# da-ch1617      59   da-ch1617              F -3.254700           0.472491
# bi-const       60    bi-const              F -3.804420           0.610740
# bi-male        61     bi-male              F  1.046311           0.217863
# bi-univtr      69   bi-univtr              F  2.671947           0.531536
# wk-univtr      79   wk-univtr              F  3.187713           0.444151
# tr-ologts     122   tr-ologts              F -0.320776           0.109358
# tr-dmixed     129   tr-dmixed              F  0.839070           0.287108
# da-escsptr    131  da-escsptr              T  0.000000           0.000000
# da-othsptr    132  da-othsptr              F  0.013595           0.090477
# sr-escsptr    133  sr-escsptr              T  0.000000           0.000000
# sr-othsptr    134  sr-othsptr              F  0.435654           0.072364
# bi-class1     161   bi-class1              T  0.000000           0.000000
# bi-class2     162   bi-class2              T  0.000000           0.000000
# bi-gauntl     163   bi-gauntl              T  0.000000           0.000000
# bi-omixed     164   bi-omixed              T  0.000000           0.000000
# bi-dempdn     168   bi-dempdn              F  0.000011           0.000013
# bi-dmixed     169   bi-dmixed              F -0.319259           0.804891
# wk-dmixed     179   wk-dmixed              F  0.508729           0.277891
# modenest       99    modenest              F  0.783541           0.068014
#
#              t-stat_14 id_06 constrained_06  value_06  standard error_06  \
# coefficient
# costutil      8.302328     1              T  0.082700           0.000000
# timeutil     10.830994     2              F  1.791423           0.183030
# sb-const      1.035044    10              F -0.331495           0.163272
# sb-chun5           inf    17              F -5.747538           1.189221
# sb-univtr     7.669210    18              T -5.000000           0.000000
# wt-const      4.139543    20              F -0.770936           0.587217
# wt-nocars     0.515857    21              F  3.416576           0.924748
# wt-carsltd    0.050086    22              F  2.023100           0.395436
# wt-chun5           inf    27              T -5.000000           0.000000
# wt-univtr     5.661912    28              F  3.432831           0.529108
# wt-ch1617     3.794095    29              F -0.370225           0.458007
# s3-const      1.315834    30              F -0.444789           0.169423
# s3-twophh     6.619112    37              F -1.442521           0.306650
# s2-onephh     3.056045    38              F -0.257307           1.234620
# s2-const      2.617678    40              F -1.308962           0.172233
# sr-nocars     3.997014    41              T -5.000000           0.000000
# sr-incu25     0.774427    44              F -1.936874           0.460599
# sr-inc2550    1.965458    45              F -1.034853           0.199275
# sr-chun5      2.913293    47              F  1.822244           0.440307
# da-const      4.371755    50              F  2.284389           0.424713
# da-carsltd    5.939546    52              F -2.350552           0.350737
# da-incu25          NaN    54              F -0.296835           0.658368
# da-inco75     1.012208    56              F  0.555739           0.274603
# da-ch1617     6.888384    59              F -2.063363           0.379634
# bi-const      6.229196    60              F -3.987930           0.506654
# bi-male       4.802608    61              F  0.689615           0.366698
# bi-univtr     5.026840    69              F  1.338162           0.802128
# wk-univtr     7.177098    79              F  0.479433           0.747899
# tr-ologts     2.933277   122              F -0.174182           0.181952
# tr-dmixed     2.922495   129              T  0.000000           0.000000
# da-escsptr         NaN   131              F -6.848638           1.849374
# da-othsptr    0.150254   132              F  0.203248           0.151188
# sr-escsptr         NaN   133              F  1.159536           0.295395
# sr-othsptr    6.020287   134              F -0.129245           0.071962
# bi-class1          NaN   161              T  0.000000           0.000000
# bi-class2          NaN   162              T  0.000000           0.000000
# bi-gauntl          NaN   163              T  0.000000           0.000000
# bi-omixed          NaN   164              F  0.005052           0.768240
# bi-dempdn     0.840289   168              T  0.000000           0.000000
# bi-dmixed     0.396649   169              T  0.000000           0.000000
# wk-dmixed     1.830682   179              T  0.000000           0.000000
# modenest     11.520247    99              F  0.703002           0.064360
#
#              t-stat_06
# coefficient
# costutil           inf
# timeutil      9.787599
# sb-const      2.030330
# sb-chun5      4.833026
# sb-univtr          inf
# wt-const      1.312864
# wt-nocars     3.694604
# wt-carsltd    5.116132
# wt-chun5           inf
# wt-univtr     6.487964
# wt-ch1617     0.808339
# s3-const      2.625323
# s3-twophh     4.704134
# s2-onephh     0.208410
# s2-const      7.599940
# sr-nocars          inf
# sr-incu25     4.205124
# sr-inc2550    5.193093
# sr-chun5      4.138576
# da-const      5.378661
# da-carsltd    6.701750
# da-incu25     0.450865
# da-inco75     2.023788
# da-ch1617     5.435137
# bi-const      7.871104
# bi-male       1.880606
# bi-univtr     1.668265
# wk-univtr     0.641040
# tr-ologts     0.957296
# tr-dmixed          NaN
# da-escsptr    3.703219
# da-othsptr    1.344342
# sr-escsptr    3.925370
# sr-othsptr    1.796012
# bi-class1          NaN
# bi-class2          NaN
# bi-gauntl          NaN
# bi-omixed     0.006576
# bi-dempdn          NaN
# bi-dmixed          NaN
# wk-dmixed          NaN
# modenest     10.922949
