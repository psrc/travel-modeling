# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Work Tour Mode

# %% [markdown]
# ## With District Constants
# ### Notes:
# - Drive alone low-income (da-incu25) reversed signs. + in 2014 estimation, suggesting low income households are more likely to drive alone. The t-stat is slightly higher in 2014 than in 2006, at 2.2 vs. 2.1, so the variable is kept. The sign could make sense as some low-income workers can only afford to live in areas far-out from the city and need cars to get around. Gas is also cheaper now, reducing costs of driving relative to 2006 (?)
# - stronger 2014 t-stats on variables related to land use (e.g., bi-omixed, bi-dmixed, tr-dintdn, tr-ointdn)
# - sign change on sr-carltd, from - to + in 2014, makes sense that HOV would increase with limited cars, higher t-stat in 2014

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\with_transit_sub_mode\results\WorkTourMode\district_constants_estimated'
dir_06 = r'R:\SoundCast\releases\soundcast_release_c1\inputs\coefficients'

fname_14 = 'WorkTourModeModel.F12'
fname_06 = 'WorkTourModeModel_psrcper1.F12'
# fname_14_old = 'WorkTourModeModel_psrcper1.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# costutil        1    costutil              F  0.977762           0.125029
# timeutil        2    timeutil              F  0.509180           0.036597
# dt-const       10    dt-const              F -3.459388           0.655352
# dt-nocars      11   dt-nocars              F -2.600324           0.726243
# dt-carsltw     13  dt-carsltw              F -1.186747           0.374868
# wt-const       20    wt-const              F -2.685198           0.760751
# s3-const       30    s3-const              F -2.413571           0.680376
# sr-hhcu5       31    sr-hhcu5              T  0.000000           0.000000
# sr-hh515       32    sr-hh515              F  0.439206           0.159623
# sr-lndist      35   sr-lndist              F -0.362872           0.084896
# s3-onephh      38   s3-onephh              F -2.056014           0.364619
# s3-twophh      39   s3-twophh              F -1.152113           0.162337
# s2-const       40    s2-const              F -1.893301           0.674836
# sr-nocars      41   sr-nocars              F -3.533004           0.608823
# sr-carsltd     42  sr-carsltd              F  0.436506           0.193985
# s2-onephh      48   s2-onephh              F -1.937469           0.334190
# da-const       50    da-const              F  1.499823           0.643018
# da-carsltw     53  da-carsltw              F -2.482546           0.269874
# da-incu25      54   da-incu25              F  0.778432           0.359042
# bi-const       60    bi-const              F -3.896737           0.748086
# bi-male        61     bi-male              F  1.770943           0.280419
# bi-ageo50      63   bi-ageo50              F -1.164350           0.370665
# wk-male        71     wk-male              F  0.921673           0.255217
# tr-omixed     124   tr-omixed              F  1.358816           0.427150
# tr-dintdn     127   tr-dintdn              F  0.009094           0.001544
# tr-dempdn     128   tr-dempdn              F  0.000042           0.000007
# da-escsptr    131  da-escsptr              F -4.511244           0.647743
# da-othsptr    132  da-othsptr              F  0.192754           0.074732
# sr-escsptr    133  sr-escsptr              F  5.481363           0.575807
# sr-othsptr    134  sr-othsptr              F  0.421796           0.089620
# bi-class2     162   bi-class2              T  0.000000           0.000000
# bi-omixed     164   bi-omixed              F  1.392996           0.608045
# bi-dempdn     168   bi-dempdn              F -0.000000           0.000008
# bi-dmixed     169   bi-dmixed              F  1.412068           0.540647
# wk-dmixed     179   wk-dmixed              F  1.768509           0.406035
# distcont1     201   distcont1              F  0.348970           0.418814
# distcont2     202   distcont2              F -0.192421           0.339680
# distcont3     203   distcont3              F  0.127299           0.202755
# distcont4     204   distcont4              T  0.000000           0.000000
# distcont5     205   distcont5              F -0.075413           0.276778
# distcont6     206   distcont6              F -0.049826           0.254231
# distcont7     207   distcont7              F -0.618200           0.392295
# distcont8     208   distcont8              F -0.594245           0.406602
# distcont9     209   distcont9              F  2.442207           0.512451
# distcon10     210   distcon10              F  0.389925           0.545104
# distcon11     211   distcon11              T  0.000000           0.000000
# modenest       99    modenest              F  0.537925           0.039645
#
#              t-stat_14 id_06 constrained_06  value_06  standard error_06  \
# coefficient
# costutil      7.820250     1              F  0.807394           0.078270
# timeutil     13.913144     2              F  0.700000           0.028915
# dt-const      5.278668    10              F -1.200000           0.407511
# dt-nocars     3.580515    11              T -2.000000           0.000000
# dt-carsltw    3.165770    13              F -0.584076           0.275347
# wt-const      3.529667    20              F -1.100000           0.478678
# s3-const      3.547411    30              F -0.300000           0.409008
# sr-hhcu5           NaN    31              F  0.409728           0.075210
# sr-hh515      2.751517    32              F  0.343029           0.053090
# sr-lndist     4.274299    35              F -0.134369           0.032601
# s3-onephh     5.638807    38              F -1.537807           0.175181
# s3-twophh     7.097055    39              F -1.564828           0.119000
# s2-const      2.805572    40              F  0.200000           0.405988
# sr-nocars     5.803002    41              F -3.600000           0.559581
# sr-carsltd    2.250210    42              F -0.152838           0.097539
# s2-onephh     5.797505    48              F -0.955798           0.152391
# da-const      2.332473    50              F  2.400000           0.438459
# da-carsltw    9.198902    53              F -2.000000           0.184153
# da-incu25     2.168082    54              F -0.400000           0.220641
# bi-const      5.208945    60              F -3.001606           0.592329
# bi-male       6.315350    61              F  1.444325           0.202166
# bi-ageo50     3.141243    63              F -1.045355           0.217693
# wk-male       3.611328    71              F  0.272291           0.205078
# tr-omixed     3.181119   124              F  1.000000           0.320142
# tr-dintdn     5.889712   127              F  0.005000           0.001509
# tr-dempdn     6.118571   128              F  0.000200           0.000004
# da-escsptr    6.964563   131              F -3.440856           0.412091
# da-othsptr    2.579288   132              F  0.116752           0.049114
# sr-escsptr    9.519452   133              F  2.238251           0.269617
# sr-othsptr    4.706480   134              F  0.133114           0.055664
# bi-class2          NaN   162              T  0.479900           0.000000
# bi-omixed     2.290941   164              F  0.200000           0.431139
# bi-dempdn     0.041565   168              F  0.000050           0.000005
# bi-dmixed     2.611809   169              F  1.000000           0.498637
# wk-dmixed     4.355553   179              F  1.400000           0.270092
# distcont1     0.833234   NaN            NaN       NaN                NaN
# distcont2     0.566478   NaN            NaN       NaN                NaN
# distcont3     0.627845   NaN            NaN       NaN                NaN
# distcont4          NaN   NaN            NaN       NaN                NaN
# distcont5     0.272466   NaN            NaN       NaN                NaN
# distcont6     0.195987   NaN            NaN       NaN                NaN
# distcont7     1.575856   NaN            NaN       NaN                NaN
# distcont8     1.461493   NaN            NaN       NaN                NaN
# distcont9     4.765737   NaN            NaN       NaN                NaN
# distcon10     0.715322   NaN            NaN       NaN                NaN
# distcon11          NaN   NaN            NaN       NaN                NaN
# modenest     13.568516    99              F  0.914054           0.067713
#
#              t-stat_06
# coefficient
# costutil     10.315451
# timeutil     24.208483
# dt-const      2.944707
# dt-nocars          inf
# dt-carsltw    2.121238
# wt-const      2.297998
# s3-const      0.733482
# sr-hhcu5      5.447758
# sr-hh515      6.461317
# sr-lndist     4.121598
# s3-onephh     8.778365
# s3-twophh    13.149787
# s2-const      0.492625
# sr-nocars     6.433382
# sr-carsltd    1.566934
# s2-onephh     6.272005
# da-const      5.473715
# da-carsltw   10.860517
# da-incu25     1.812902
# bi-const      5.067468
# bi-male       7.144253
# bi-ageo50     4.801965
# wk-male       1.327742
# tr-omixed     3.123610
# tr-dintdn     3.312487
# tr-dempdn    48.151731
# da-escsptr    8.349754
# da-othsptr    2.377151
# sr-escsptr    8.301596
# sr-othsptr    2.391361
# bi-class2          inf
# bi-omixed     0.463887
# bi-dempdn    10.170070
# bi-dmixed     2.005466
# wk-dmixed     5.183410
# distcont1          NaN
# distcont2          NaN
# distcont3          NaN
# distcont4          NaN
# distcont5          NaN
# distcont6          NaN
# distcont7          NaN
# distcont8          NaN
# distcont9          NaN
# distcon10          NaN
# distcon11          NaN
# modenest     13.498852

# %% [markdown]
# ## Without District Constants

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\with_transit_sub_mode\results\WorkTourMode\district_constants_not_estimated'

fname_14 = 'WorkTourModeModel.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)
# df_14_old = load_f12(dir_14_old, fname_14_old)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# costutil        1    costutil              F  0.969784           0.123657
# timeutil        2    timeutil              F  0.495524           0.034801
# dt-const       10    dt-const              F -3.349760           0.646944
# dt-nocars      11   dt-nocars              F -2.555541           0.724067
# dt-carsltw     13  dt-carsltw              F -1.185410           0.373949
# wt-const       20    wt-const              F -2.446922           0.710912
# s3-const       30    s3-const              F -2.310048           0.669952
# sr-hhcu5       31    sr-hhcu5              T  0.000000           0.000000
# sr-hh515       32    sr-hh515              F  0.437282           0.158283
# sr-lndist      35   sr-lndist              F -0.353798           0.083958
# s3-onephh      38   s3-onephh              F -2.043329           0.361926
# s3-twophh      39   s3-twophh              F -1.151256           0.162277
# s2-const       40    s2-const              F -1.790660           0.664369
# sr-nocars      41   sr-nocars              F -3.484416           0.600363
# sr-carsltd     42  sr-carsltd              F  0.424713           0.192179
# s2-onephh      48   s2-onephh              F -1.925823           0.331322
# da-const       50    da-const              F  1.594130           0.637334
# da-carsltw     53  da-carsltw              F -2.469334           0.265991
# da-incu25      54   da-incu25              F  0.750715           0.356248
# bi-const       60    bi-const              F -3.806439           0.737718
# bi-male        61     bi-male              F  1.749541           0.276825
# bi-ageo50      63   bi-ageo50              F -1.158220           0.367479
# wk-male        71     wk-male              F  0.916275           0.252520
# tr-omixed     124   tr-omixed              F  1.245349           0.403360
# tr-dintdn     127   tr-dintdn              F  0.008821           0.001511
# tr-dempdn     128   tr-dempdn              F  0.000043           0.000007
# da-escsptr    131  da-escsptr              F -4.460683           0.641054
# da-othsptr    132  da-othsptr              F  0.190153           0.073940
# sr-escsptr    133  sr-escsptr              F  5.457498           0.567907
# sr-othsptr    134  sr-othsptr              F  0.417627           0.088644
# bi-class2     162   bi-class2              T  0.000000           0.000000
# bi-omixed     164   bi-omixed              F  1.414451           0.599441
# bi-dempdn     168   bi-dempdn              F -0.000000           0.000008
# bi-dmixed     169   bi-dmixed              F  1.396270           0.535048
# wk-dmixed     179   wk-dmixed              F  1.780560           0.401526
# distcont1     201   distcont1              T  0.000000           0.000000
# distcont2     202   distcont2              T  0.000000           0.000000
# distcont3     203   distcont3              T  0.000000           0.000000
# distcont4     204   distcont4              T  0.000000           0.000000
# distcont5     205   distcont5              T  0.000000           0.000000
# distcont6     206   distcont6              T  0.000000           0.000000
# distcont7     207   distcont7              T  0.000000           0.000000
# distcont8     208   distcont8              T  0.000000           0.000000
# distcont9     209   distcont9              T  0.000000           0.000000
# distcon10     210   distcon10              T  0.000000           0.000000
# distcon11     211   distcon11              T  0.000000           0.000000
# modenest       99    modenest              F  0.542009           0.039624
#
#              t-stat_14 id_06 constrained_06  value_06  standard error_06  \
# coefficient
# costutil      7.842529     1              F  0.807394           0.078270
# timeutil     14.238814     2              F  0.700000           0.028915
# dt-const      5.177822    10              F -1.200000           0.407511
# dt-nocars     3.529425    11              T -2.000000           0.000000
# dt-carsltw    3.169976    13              F -0.584076           0.275347
# wt-const      3.441947    20              F -1.100000           0.478678
# s3-const      3.448078    30              F -0.300000           0.409008
# sr-hhcu5           NaN    31              F  0.409728           0.075210
# sr-hh515      2.762657    32              F  0.343029           0.053090
# sr-lndist     4.214002    35              F -0.134369           0.032601
# s3-onephh     5.645704    38              F -1.537807           0.175181
# s3-twophh     7.094404    39              F -1.564828           0.119000
# s2-const      2.695279    40              F  0.200000           0.405988
# sr-nocars     5.803851    41              F -3.600000           0.559581
# sr-carsltd    2.209986    42              F -0.152838           0.097539
# s2-onephh     5.812535    48              F -0.955798           0.152391
# da-const      2.501246    50              F  2.400000           0.438459
# da-carsltw    9.283528    53              F -2.000000           0.184153
# da-incu25     2.107284    54              F -0.400000           0.220641
# bi-const      5.159746    60              F -3.001606           0.592329
# bi-male       6.320028    61              F  1.444325           0.202166
# bi-ageo50     3.151800    63              F -1.045355           0.217693
# wk-male       3.628520    71              F  0.272291           0.205078
# tr-omixed     3.087439   124              F  1.000000           0.320142
# tr-dintdn     5.838613   127              F  0.005000           0.001509
# tr-dempdn     6.345635   128              F  0.000200           0.000004
# da-escsptr    6.958353   131              F -3.440856           0.412091
# da-othsptr    2.571710   132              F  0.116752           0.049114
# sr-escsptr    9.609837   133              F  2.238251           0.269617
# sr-othsptr    4.711263   134              F  0.133114           0.055664
# bi-class2          NaN   162              T  0.479900           0.000000
# bi-omixed     2.359619   164              F  0.200000           0.431139
# bi-dempdn     0.037887   168              F  0.000050           0.000005
# bi-dmixed     2.609613   169              F  1.000000           0.498637
# wk-dmixed     4.434480   179              F  1.400000           0.270092
# distcont1          NaN   NaN            NaN       NaN                NaN
# distcont2          NaN   NaN            NaN       NaN                NaN
# distcont3          NaN   NaN            NaN       NaN                NaN
# distcont4          NaN   NaN            NaN       NaN                NaN
# distcont5          NaN   NaN            NaN       NaN                NaN
# distcont6          NaN   NaN            NaN       NaN                NaN
# distcont7          NaN   NaN            NaN       NaN                NaN
# distcont8          NaN   NaN            NaN       NaN                NaN
# distcont9          NaN   NaN            NaN       NaN                NaN
# distcon10          NaN   NaN            NaN       NaN                NaN
# distcon11          NaN   NaN            NaN       NaN                NaN
# modenest     13.678791    99              F  0.914054           0.067713
#
#              t-stat_06
# coefficient
# costutil     10.315451
# timeutil     24.208483
# dt-const      2.944707
# dt-nocars          inf
# dt-carsltw    2.121238
# wt-const      2.297998
# s3-const      0.733482
# sr-hhcu5      5.447758
# sr-hh515      6.461317
# sr-lndist     4.121598
# s3-onephh     8.778365
# s3-twophh    13.149787
# s2-const      0.492625
# sr-nocars     6.433382
# sr-carsltd    1.566934
# s2-onephh     6.272005
# da-const      5.473715
# da-carsltw   10.860517
# da-incu25     1.812902
# bi-const      5.067468
# bi-male       7.144253
# bi-ageo50     4.801965
# wk-male       1.327742
# tr-omixed     3.123610
# tr-dintdn     3.312487
# tr-dempdn    48.151731
# da-escsptr    8.349754
# da-othsptr    2.377151
# sr-escsptr    8.301596
# sr-othsptr    2.391361
# bi-class2          inf
# bi-omixed     0.463887
# bi-dempdn    10.170070
# bi-dmixed     2.005466
# wk-dmixed     5.183410
# distcont1          NaN
# distcont2          NaN
# distcont3          NaN
# distcont4          NaN
# distcont5          NaN
# distcont6          NaN
# distcont7          NaN
# distcont8          NaN
# distcont9          NaN
# distcon10          NaN
# distcon11          NaN
# modenest     13.498852
