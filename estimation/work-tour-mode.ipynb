# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Work Tour Mode

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results\F12_archive'
dir_06 = r'R:\SoundCast\releases\soundcast_release_c1\inputs\coefficients'
# dir_14_old = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results_archive\withoutNodeToNodeDistances\WorkTourMode'

fname_14 = 'WorkTourModeModel.F12'
fname_06 = 'WorkTourModeModel_psrcper1.F12'
# fname_14_old = 'WorkTourModeModel_psrcper1.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)
# df_14_old = load_f12(dir_14_old, fname_14_old)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])
# Out:
# Axes(0.125,0.125;0.775x0.775)
# ['t-stat_14', 't-stat_06']
# Axes(0.125,0.125;0.775x0.775)

# %% [markdown]
# ### Notes:
# - Drive alone low-income (da-incu25) reversed signs. + in 2014 estimation, suggesting low income households are more likely to drive alone. The t-stat is slightly higher in 2014 than in 2006, at 2.2 vs. 2.1, so the variable is kept. The sign could make sense as some low-income workers can only afford to live in areas far-out from the city and need cars to get around. Gas is also cheaper now, reducing costs of driving relative to 2006 (?)
# - stronger 2014 t-stats on variables related to land use (e.g., bi-omixed, bi-dmixed, tr-dintdn, tr-ointdn)

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# costutil        1    costutil              F  0.964643           0.122432
# timeutil        2    timeutil              F  0.483202           0.034521
# dt-const       10    dt-const              F -3.040537           0.636951
# dt-nocars      11   dt-nocars              F -2.485528           0.728890
# dt-carsltw     13  dt-carsltw              F -1.143394           0.377105
# wt-const       20    wt-const              F -2.719801           0.764519
# s3-const       30    s3-const              F -2.173344           0.664696
# sr-hhcu5       31    sr-hhcu5              T  0.000000           0.000000
# sr-hh515       32    sr-hh515              F  0.423971           0.155904
# sr-lndist      35   sr-lndist              F -0.369760           0.083186
# s3-onephh      38   s3-onephh              F -1.994745           0.357016
# s3-twophh      39   s3-twophh              F -1.148454           0.162195
# s2-const       40    s2-const              F -1.653847           0.659244
# sr-nocars      41   sr-nocars              F -3.388430           0.593134
# sr-carsltd     42  sr-carsltd              F  0.446264           0.189902
# s2-onephh      48   s2-onephh              F -1.879048           0.325992
# da-const       50    da-const              F  1.627050           0.632515
# da-carsltw     53  da-carsltw              F -2.400118           0.261717
# da-incu25      54   da-incu25              F  0.783999           0.351933
# bi-const       60    bi-const              F -3.731185           0.729049
# bi-male        61     bi-male              F  1.708791           0.271487
# bi-ageo50      63   bi-ageo50              F -1.167202           0.362948
# wk-male        71     wk-male              F  0.890660           0.248042
# tr-omixed     124   tr-omixed              F  1.387236           0.422272
# tr-ointdn     126   tr-ointdn              F  0.005138           0.001756
# tr-dintdn     127   tr-dintdn              F  0.008595           0.001501
# tr-dempdn     128   tr-dempdn              F  0.000042           0.000007
# da-escsptr    131  da-escsptr              F -4.450126           0.632632
# da-othsptr    132  da-othsptr              F  0.188514           0.073421
# sr-escsptr    133  sr-escsptr              F  5.320494           0.558110
# sr-othsptr    134  sr-othsptr              F  0.413432           0.087649
# bi-class2     162   bi-class2              T  0.000000           0.000000
# bi-omixed     164   bi-omixed              F  1.568704           0.598675
# bi-dempdn     168   bi-dempdn              F -0.000001           0.000008
# bi-dmixed     169   bi-dmixed              F  1.352734           0.525353
# wk-dmixed     179   wk-dmixed              F  1.833229           0.399415
# distcont1     201   distcont1              F  0.866006           0.445935
# distcont2     202   distcont2              F  0.243515           0.361761
# distcont3     203   distcont3              F  0.217820           0.205092
# distcont4     204   distcont4              T  0.000000           0.000000
# distcont5     205   distcont5              F  0.251397           0.291040
# distcont6     206   distcont6              F  0.235539           0.270573
# distcont7     207   distcont7              F -0.128039           0.415451
# distcont8     208   distcont8              F -0.341499           0.409502
# distcont9     209   distcont9              F  2.764515           0.524818
# distcon10     210   distcon10              F  0.868463           0.552616
# distcon11     211   distcon11              T -4.000000           0.000000
# modenest       99    modenest              F  0.550234           0.039934
#
#              t-stat_14 id_06 constrained_06  value_06  standard error_06  \
# coefficient
# costutil      7.878982     1              F  0.807394           0.078270
# timeutil     13.997308     2              F  0.700000           0.028915
# dt-const      4.773579    10              F -1.200000           0.407511
# dt-nocars     3.410017    11              T -2.000000           0.000000
# dt-carsltw    3.032027    13              F -0.584076           0.275347
# wt-const      3.557530    20              F -1.100000           0.478678
# s3-const      3.269679    30              F -0.300000           0.409008
# sr-hhcu5           NaN    31              F  0.409728           0.075210
# sr-hh515      2.719428    32              F  0.343029           0.053090
# sr-lndist     4.445000    35              F -0.134369           0.032601
# s3-onephh     5.587269    38              F -1.537807           0.175181
# s3-twophh     7.080698    39              F -1.564828           0.119000
# s2-const      2.508703    40              F  0.200000           0.405988
# sr-nocars     5.712753    41              F -3.600000           0.559581
# sr-carsltd    2.349970    42              F -0.152838           0.097539
# s2-onephh     5.764088    48              F -0.955798           0.152391
# da-const      2.572351    50              F  2.400000           0.438459
# da-carsltw    9.170649    53              F -2.000000           0.184153
# da-incu25     2.227695    54              F -0.400000           0.220641
# bi-const      5.117876    60              F -3.001606           0.592329
# bi-male       6.294181    61              F  1.444325           0.202166
# bi-ageo50     3.215894    63              F -1.045355           0.217693
# wk-male       3.590757    71              F  0.272291           0.205078
# tr-omixed     3.285170   124              F  1.000000           0.320142
# tr-ointdn     2.925424   NaN            NaN       NaN                NaN
# tr-dintdn     5.725268   127              F  0.005000           0.001509
# tr-dempdn     6.228294   128              F  0.000200           0.000004
# da-escsptr    7.034310   131              F -3.440856           0.412091
# da-othsptr    2.567564   132              F  0.116752           0.049114
# sr-escsptr    9.533064   133              F  2.238251           0.269617
# sr-othsptr    4.716921   134              F  0.133114           0.055664
# bi-class2          NaN   162              T  0.479900           0.000000
# bi-omixed     2.620293   164              F  0.200000           0.431139
# bi-dempdn     0.081939   168              F  0.000050           0.000005
# bi-dmixed     2.574906   169              F  1.000000           0.498637
# wk-dmixed     4.589783   179              F  1.400000           0.270092
# distcont1     1.942001   NaN            NaN       NaN                NaN
# distcont2     0.673136   NaN            NaN       NaN                NaN
# distcont3     1.062063   NaN            NaN       NaN                NaN
# distcont4          NaN   NaN            NaN       NaN                NaN
# distcont5     0.863789   NaN            NaN       NaN                NaN
# distcont6     0.870518   NaN            NaN       NaN                NaN
# distcont7     0.308192   NaN            NaN       NaN                NaN
# distcont8     0.833937   NaN            NaN       NaN                NaN
# distcont9     5.267569   NaN            NaN       NaN                NaN
# distcon10     1.571550   NaN            NaN       NaN                NaN
# distcon11          inf   NaN            NaN       NaN                NaN
# modenest     13.778527    99              F  0.914054           0.067713
#
#              t-stat_06
# coefficient
# costutil     10.315451
# timeutil     24.208483
# dt-const      2.944707
# dt-nocars          inf
# dt-carsltw    2.121238
# wt-const      2.297998
# s3-const      0.733482
# sr-hhcu5      5.447758
# sr-hh515      6.461317
# sr-lndist     4.121598
# s3-onephh     8.778365
# s3-twophh    13.149787
# s2-const      0.492625
# sr-nocars     6.433382
# sr-carsltd    1.566934
# s2-onephh     6.272005
# da-const      5.473715
# da-carsltw   10.860517
# da-incu25     1.812902
# bi-const      5.067468
# bi-male       7.144253
# bi-ageo50     4.801965
# wk-male       1.327742
# tr-omixed     3.123610
# tr-ointdn          NaN
# tr-dintdn     3.312487
# tr-dempdn    48.151731
# da-escsptr    8.349754
# da-othsptr    2.377151
# sr-escsptr    8.301596
# sr-othsptr    2.391361
# bi-class2          inf
# bi-omixed     0.463887
# bi-dempdn    10.170070
# bi-dmixed     2.005466
# wk-dmixed     5.183410
# distcont1          NaN
# distcont2          NaN
# distcont3          NaN
# distcont4          NaN
# distcont5          NaN
# distcont6          NaN
# distcont7          NaN
# distcont8          NaN
# distcont9          NaN
# distcon10          NaN
# distcon11          NaN
# modenest     13.498852
