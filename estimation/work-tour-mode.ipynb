# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Work Tour Mode

# %% [markdown]
# ## With District Constants
# ### Notes:
# - Drive alone low-income (da-incu25) reversed signs. + in 2014 estimation, suggesting low income households are more likely to drive alone. The t-stat is slightly higher in 2014 than in 2006, at 2.2 vs. 2.1, so the variable is kept. The sign could make sense as some low-income workers can only afford to live in areas far-out from the city and need cars to get around. Gas is also cheaper now, reducing costs of driving relative to 2006 (?)
# - stronger 2014 t-stats on variables related to land use (e.g., bi-omixed, bi-dmixed, tr-dintdn, tr-ointdn)
# - sign change on sr-carltd, from - to + in 2014, makes sense that HOV would increase with limited cars, higher t-stat in 2014

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\with_transit_sub_mode\results\WorkTourMode\district_constants_estimated'
dir_06 = r'R:\SoundCast\releases\soundcast_release_c1\inputs\coefficients'

fname_14 = 'WorkTourModeModel.F12'
fname_06 = 'WorkTourModeModel_psrcper1.F12'
# fname_14_old = 'WorkTourModeModel_psrcper1.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# costutil        1    costutil              F  0.977762           0.125029
# timeutil        2    timeutil              F  0.509180           0.036597
# dt-const       10    dt-const              F -3.459388           0.655352
# dt-nocars      11   dt-nocars              F -2.600324           0.726243
# dt-carsltw     13  dt-carsltw              F -1.186747           0.374868
# wt-const       20    wt-const              F -2.685198           0.760751
# s3-const       30    s3-const              F -2.413571           0.680376
# sr-hhcu5       31    sr-hhcu5              T  0.000000           0.000000
# sr-hh515       32    sr-hh515              F  0.439206           0.159623
# sr-lndist      35   sr-lndist              F -0.362872           0.084896
# s3-onephh      38   s3-onephh              F -2.056014           0.364619
# s3-twophh      39   s3-twophh              F -1.152113           0.162337
# s2-const       40    s2-const              F -1.893301           0.674836
# sr-nocars      41   sr-nocars              F -3.533004           0.608823
# sr-carsltd     42  sr-carsltd              F  0.436506           0.193985
# s2-onephh      48   s2-onephh              F -1.937469           0.334190
# da-const       50    da-const              F  1.499823           0.643018
# da-carsltw     53  da-carsltw              F -2.482546           0.269874
# da-incu25      54   da-incu25              F  0.778432           0.359042
# bi-const       60    bi-const              F -3.896737           0.748086
# bi-male        61     bi-male              F  1.770943           0.280419
# bi-ageo50      63   bi-ageo50              F -1.164350           0.370665
# wk-male        71     wk-male              F  0.921673           0.255217
# tr-omixed     124   tr-omixed              F  1.358816           0.427150
# tr-dintdn     127   tr-dintdn              F  0.009094           0.001544
# tr-dempdn     128   tr-dempdn              F  0.000042           0.000007
# da-escsptr    131  da-escsptr              F -4.511244           0.647743
# da-othsptr    132  da-othsptr              F  0.192754           0.074732
# sr-escsptr    133  sr-escsptr              F  5.481363           0.575807
# sr-othsptr    134  sr-othsptr              F  0.421796           0.089620
# bi-class2     162   bi-class2              T  0.000000           0.000000
# bi-omixed     164   bi-omixed              F  1.392996           0.608045
# bi-dempdn     168   bi-dempdn              F -0.000000           0.000008
# bi-dmixed     169   bi-dmixed              F  1.412068           0.540647
# wk-dmixed     179   wk-dmixed              F  1.768509           0.406035
# modenest       99    modenest              F  0.537925           0.039645
#
#              t-stat_14 id_06 constrained_06  value_06  standard error_06  \
# coefficient
# costutil      7.820250     1              F  0.807394           0.078270
# timeutil     13.913144     2              F  0.700000           0.028915
# dt-const      5.278668    10              F -1.200000           0.407511
# dt-nocars     3.580515    11              T -2.000000           0.000000
# dt-carsltw    3.165770    13              F -0.584076           0.275347
# wt-const      3.529667    20              F -1.100000           0.478678
# s3-const      3.547411    30              F -0.300000           0.409008
# sr-hhcu5           NaN    31              F  0.409728           0.075210
# sr-hh515      2.751517    32              F  0.343029           0.053090
# sr-lndist     4.274299    35              F -0.134369           0.032601
# s3-onephh     5.638807    38              F -1.537807           0.175181
# s3-twophh     7.097055    39              F -1.564828           0.119000
# s2-const      2.805572    40              F  0.200000           0.405988
# sr-nocars     5.803002    41              F -3.600000           0.559581
# sr-carsltd    2.250210    42              F -0.152838           0.097539
# s2-onephh     5.797505    48              F -0.955798           0.152391
# da-const      2.332473    50              F  2.400000           0.438459
# da-carsltw    9.198902    53              F -2.000000           0.184153
# da-incu25     2.168082    54              F -0.400000           0.220641
# bi-const      5.208945    60              F -3.001606           0.592329
# bi-male       6.315350    61              F  1.444325           0.202166
# bi-ageo50     3.141243    63              F -1.045355           0.217693
# wk-male       3.611328    71              F  0.272291           0.205078
# tr-omixed     3.181119   124              F  1.000000           0.320142
# tr-dintdn     5.889712   127              F  0.005000           0.001509
# tr-dempdn     6.118571   128              F  0.000200           0.000004
# da-escsptr    6.964563   131              F -3.440856           0.412091
# da-othsptr    2.579288   132              F  0.116752           0.049114
# sr-escsptr    9.519452   133              F  2.238251           0.269617
# sr-othsptr    4.706480   134              F  0.133114           0.055664
# bi-class2          NaN   162              T  0.479900           0.000000
# bi-omixed     2.290941   164              F  0.200000           0.431139
# bi-dempdn     0.041565   168              F  0.000050           0.000005
# bi-dmixed     2.611809   169              F  1.000000           0.498637
# wk-dmixed     4.355553   179              F  1.400000           0.270092
# modenest     13.568516    99              F  0.914054           0.067713
#
#              t-stat_06
# coefficient
# costutil     10.315451
# timeutil     24.208483
# dt-const      2.944707
# dt-nocars          inf
# dt-carsltw    2.121238
# wt-const      2.297998
# s3-const      0.733482
# sr-hhcu5      5.447758
# sr-hh515      6.461317
# sr-lndist     4.121598
# s3-onephh     8.778365
# s3-twophh    13.149787
# s2-const      0.492625
# sr-nocars     6.433382
# sr-carsltd    1.566934
# s2-onephh     6.272005
# da-const      5.473715
# da-carsltw   10.860517
# da-incu25     1.812902
# bi-const      5.067468
# bi-male       7.144253
# bi-ageo50     4.801965
# wk-male       1.327742
# tr-omixed     3.123610
# tr-dintdn     3.312487
# tr-dempdn    48.151731
# da-escsptr    8.349754
# da-othsptr    2.377151
# sr-escsptr    8.301596
# sr-othsptr    2.391361
# bi-class2          inf
# bi-omixed     0.463887
# bi-dempdn    10.170070
# bi-dmixed     2.005466
# wk-dmixed     5.183410
# modenest     13.498852

# %% [markdown]
# ## Without District Constants

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results\WorkTourMode\estimated_district_constants'

fname_14 = 'WorkTourModeModel.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)
# df_14_old = load_f12(dir_14_old, fname_14_old)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# costutil        1    costutil              F  0.984553           0.124484
# timeutil        2    timeutil              F  0.502469           0.036014
# dt-const       10    dt-const              F -3.378392           0.648865
# dt-nocars      11   dt-nocars              F -2.614614           0.726713
# dt-carsltw     13  dt-carsltw              F -1.181511           0.375422
# wt-const       20    wt-const              F -2.551407           0.752027
# s3-const       30    s3-const              F -2.367531           0.674262
# sr-hhcu5       31    sr-hhcu5              T  0.000000           0.000000
# sr-hh515       32    sr-hh515              F  0.435560           0.158053
# sr-lndist      35   sr-lndist              F -0.360873           0.084157
# s3-onephh      38   s3-onephh              F -2.039751           0.361783
# s3-twophh      39   s3-twophh              F -1.151783           0.162280
# s2-const       40    s2-const              F -1.847194           0.668719
# sr-nocars      41   sr-nocars              F -3.510294           0.602854
# sr-carsltd     42  sr-carsltd              F  0.429743           0.192131
# s2-onephh      48   s2-onephh              F -1.921059           0.331105
# da-const       50    da-const              F  1.511753           0.638242
# da-carsltw     53  da-carsltw              F -2.462163           0.267206
# da-incu25      54   da-incu25              F  0.775962           0.356191
# bi-const       60    bi-const              F -3.828346           0.740897
# bi-male        61     bi-male              F  1.747676           0.277278
# bi-ageo50      63   bi-ageo50              F -1.164496           0.368061
# wk-male        71     wk-male              F  0.911254           0.252735
# tr-omixed     124   tr-omixed              F  1.354915           0.424155
# tr-dintdn     127   tr-dintdn              F  0.008887           0.001525
# tr-dempdn     128   tr-dempdn              F  0.000043           0.000007
# da-escsptr    131  da-escsptr              F -4.483427           0.641672
# da-othsptr    132  da-othsptr              F  0.191749           0.074112
# sr-escsptr    133  sr-escsptr              F  5.418143           0.569394
# sr-othsptr    134  sr-othsptr              F  0.419286           0.088773
# bi-class2     162   bi-class2              T  0.000000           0.000000
# bi-omixed     164   bi-omixed              F  1.405523           0.603470
# bi-dempdn     168   bi-dempdn              F -0.000001           0.000008
# bi-dmixed     169   bi-dmixed              F  1.371860           0.533867
# wk-dmixed     179   wk-dmixed              F  1.763883           0.402824
# modenest       99    modenest              F  0.543046           0.039935
#
#              t-stat_14 id_06 constrained_06  value_06  standard error_06  \
# coefficient
# costutil      7.909080     1              F  0.807394           0.078270
# timeutil     13.952069     2              F  0.700000           0.028915
# dt-const      5.206617    10              F -1.200000           0.407511
# dt-nocars     3.597866    11              T -2.000000           0.000000
# dt-carsltw    3.147159    13              F -0.584076           0.275347
# wt-const      3.392704    20              F -1.100000           0.478678
# s3-const      3.511290    30              F -0.300000           0.409008
# sr-hhcu5           NaN    31              F  0.409728           0.075210
# sr-hh515      2.755789    32              F  0.343029           0.053090
# sr-lndist     4.288075    35              F -0.134369           0.032601
# s3-onephh     5.638053    38              F -1.537807           0.175181
# s3-twophh     7.097517    39              F -1.564828           0.119000
# s2-const      2.762288    40              F  0.200000           0.405988
# sr-nocars     5.822797    41              F -3.600000           0.559581
# sr-carsltd    2.236717    42              F -0.152838           0.097539
# s2-onephh     5.801957    48              F -0.955798           0.152391
# da-const      2.368619    50              F  2.400000           0.438459
# da-carsltw    9.214492    53              F -2.000000           0.184153
# da-incu25     2.178501    54              F -0.400000           0.220641
# bi-const      5.167180    60              F -3.001606           0.592329
# bi-male       6.302966    61              F  1.444325           0.202166
# bi-ageo50     3.163869    63              F -1.045355           0.217693
# wk-male       3.605577    71              F  0.272291           0.205078
# tr-omixed     3.194386   124              F  1.000000           0.320142
# tr-dintdn     5.828495   127              F  0.005000           0.001509
# tr-dempdn     6.244066   128              F  0.000200           0.000004
# da-escsptr    6.987096   131              F -3.440856           0.412091
# da-othsptr    2.587297   132              F  0.116752           0.049114
# sr-escsptr    9.515633   133              F  2.238251           0.269617
# sr-othsptr    4.723125   134              F  0.133114           0.055664
# bi-class2          NaN   162              T  0.479900           0.000000
# bi-omixed     2.329069   164              F  0.200000           0.431139
# bi-dempdn     0.094957   168              F  0.000050           0.000005
# bi-dmixed     2.569666   169              F  1.000000           0.498637
# wk-dmixed     4.378796   179              F  1.400000           0.270092
# modenest     13.598085    99              F  0.914054           0.067713
#
#              t-stat_06
# coefficient
# costutil     10.315451
# timeutil     24.208483
# dt-const      2.944707
# dt-nocars          inf
# dt-carsltw    2.121238
# wt-const      2.297998
# s3-const      0.733482
# sr-hhcu5      5.447758
# sr-hh515      6.461317
# sr-lndist     4.121598
# s3-onephh     8.778365
# s3-twophh    13.149787
# s2-const      0.492625
# sr-nocars     6.433382
# sr-carsltd    1.566934
# s2-onephh     6.272005
# da-const      5.473715
# da-carsltw   10.860517
# da-incu25     1.812902
# bi-const      5.067468
# bi-male       7.144253
# bi-ageo50     4.801965
# wk-male       1.327742
# tr-omixed     3.123610
# tr-dintdn     3.312487
# tr-dempdn    48.151731
# da-escsptr    8.349754
# da-othsptr    2.377151
# sr-escsptr    8.301596
# sr-othsptr    2.391361
# bi-class2          inf
# bi-omixed     0.463887
# bi-dempdn    10.170070
# bi-dmixed     2.005466
# wk-dmixed     5.183410
# modenest     13.498852
