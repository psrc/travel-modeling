# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Transit Pass Ownership

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\New_06_20_16\estimation\results\TransitPassOwnership'
dir_06 = r'R:\SoundCast\releases\soundcast_release_c1\inputs\coefficients'

fname_14 = 'TransitPassOwnershipModel.F12'
fname_06 = 'TransitPassOwnershipCoefficients_SACOG-v1.5.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])
# Out:
# Axes(0.125,0.125;0.775x0.775)
# ['t-stat_14', 't-stat_06']
# Axes(0.125,0.125;0.775x0.775)

# %% [markdown]
# ### Notes:
# - coefficient wt-const not used in 2014 model
# - bi-male (male & bike) was negative for 2014, with t-stat ~ 0.4
# - sr-drtowork had very small t-stat ~ 0.25

# %%
df
# Out:
#             id_14 coefficient constrained_14  value_14  standard error_14  \
# coefficient
# Pass_Cons       1   Pass_Cons              F   -4.6047                NaN
# PartTime        2    PartTime              F   -0.3179                NaN
# OtherWkr        3    OtherWkr              F    0.3116                NaN
# UnivStud        4    UnivStud              F    0.6738                NaN
# RetiredA        5    RetiredA              F   -1.2577                NaN
# NonWorkA        6    NonWorkA              F   -4.3318                NaN
# HiScStud        7    HiScStud              F   -1.2722                NaN
# ChildU16        8    ChildU16              T   -1.6896                NaN
# LogHHIncm       9   LogHHIncm              F   -0.4204                NaN
# MsgIncome      10   MsgIncome              F   -4.7078                NaN
# MsgUWParc      11   MsgUWParc              F    4.4445                NaN
# ...
