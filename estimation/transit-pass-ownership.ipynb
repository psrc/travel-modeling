# %%
import pandas as pd
from estimation import *

% matplotlib inline

# %% [markdown]
# # Transit Pass Ownership

# %%
dir_14 = r'R:\SoundCastDocuments\2014Estimation\with_transit_sub_mode\results\TransitPassOwnership'
dir_06 = r'R:\SoundCast\releases\soundcast_release_c1\inputs\coefficients'

fname_14 = 'TransitPassOwnershipModel.F12'
fname_06 = 'TransitPassOwnershipCoefficients_SACOG-v1.5.F12'

df_14 = load_f12(dir_14, fname_14)
df_06 = load_f12(dir_06, fname_06)

# Join old and new results
df = compare_df(df_14,df_06,suffixes=['_14','_06'])

# %%
df
# Out:
#             id_14 coefficient constrained_14   value_14  standard error_14  \
# coefficient
# Pass_Cons       1   Pass_Cons              F  -1.599776           0.550344
# PartTime        2    PartTime              F  -0.628762           0.095510
# OtherWkr        3    OtherWkr              F  -1.152864           0.399951
# UnivStud        4    UnivStud              F   1.486042           0.297385
# RetiredA        5    RetiredA              F -46.798360          44.185150
# NonWorkA        6    NonWorkA              F  -2.481564           0.831209
# HiScStud        7    HiScStud              F   4.960836           1.639944
# ChildU16        8    ChildU16              T  -2.408100           0.000000
# LogHHIncm       9   LogHHIncm              F  -0.070920           0.038355
# MsgIncome      10   MsgIncome              F  -0.884061           0.448344
# MsgUWParc      11   MsgUWParc              F   0.561731           0.166623
# MsgUSParc      12   MsgUSParc              F  -2.086695           0.241013
# HomeTDist1     13  HomeTDist1              F  -5.347357           0.599181
# HomeTDist2     14  HomeTDist2              F   0.026240           0.280505
# HomeTDistX     15  HomeTDistX              F  -0.513370           0.121223
# UWNoPath       22    UWNoPath              F  -0.054737           0.111695
# UWGTDiff       23    UWGTDiff              F   0.005115           0.001941
# USNoPath       25    USNoPath              F  -0.349547           0.263723
# HAgLSWork      26   HAgLSWork              F   0.267853           0.028367
# HAgLSStud      27   HAgLSStud              F  -0.106197           0.198623
# HAgLSNonW      28   HAgLSNonW              F   0.417546           0.092694
# HAgLSReti      29   HAgLSReti              F   4.498690           4.282697
# WAgLSWork      30   WAgLSWork              F   0.412387           0.016749
# SAGLSScho      31   SAGLSScho              F   0.030909           0.055590
# CostChange     32  CostChange              T   0.000000           0.000000
#
#              t-stat_14 id_06 constrained_06  value_06  standard error_06  \
# coefficient
# Pass_Cons     2.906866     1              F -4.500000           0.817459
# PartTime      6.583202     2              F -0.328895           0.127412
# OtherWkr      2.882515     3              F  0.315659           0.294631
# UnivStud      4.997027     4              F  0.607333           0.214427
# RetiredA      1.059142     5              F -0.900700           0.554513
# NonWorkA      2.985485     6              F -3.212448           0.864739
# HiScStud      3.025003     7              F -1.981310           1.275802
# ChildU16           inf     8              F -2.408102           1.297954
# LogHHIncm     1.849031     9              F -0.413270           0.051307
# MsgIncome     1.971835    10              F -4.633555           0.570674
# MsgUWParc     3.371261    11              F  2.243713           0.224641
# MsgUSParc     8.658029    12              F  0.931921           0.513313
# HomeTDist1    8.924442    13              F -4.000000           0.719813
# HomeTDist2    0.093545    14              F -0.500000           0.348503
# HomeTDistX    4.234924    15              F -0.522814           0.165416
# UWNoPath      0.490055    22              F -0.181291           0.165026
# UWGTDiff      2.635363    23              F  0.017193           0.006954
# USNoPath      1.325432    25              F -0.869276           0.321394
# HAgLSWork     9.442369    26              F  0.250000           0.033181
# HAgLSStud     0.534664    27              F  0.238231           0.162569
# HAgLSNonW     4.504547    28              F  0.406058           0.105666
# HAgLSReti     1.050434    29              F  0.309659           0.065308
# WAgLSWork    24.621634    30              F  1.000000           0.026968
# SAGLSScho     0.556015    31              F  0.700000           0.100032
# CostChange         NaN    32              T  0.000000           0.000000
#
#              t-stat_06
# coefficient
# Pass_Cons     5.504863
# PartTime      2.581356
# OtherWkr      1.071370
# UnivStud      2.832358
# RetiredA      1.624310
# NonWorkA      3.714932
# HiScStud      1.552992
# ChildU16      1.855306
# LogHHIncm     8.054882
# MsgIncome     8.119449
# MsgUWParc     9.987987
# MsgUSParc     1.815502
# HomeTDist1    5.557003
# HomeTDist2    1.434707
# HomeTDistX    3.160608
# UWNoPath      1.098559
# UWGTDiff      2.472356
# USNoPath      2.704702
# HAgLSWork     7.534374
# HAgLSStud     1.465417
# HAgLSNonW     3.842841
# HAgLSReti     4.741520
# WAgLSWork    37.081525
# SAGLSScho     6.997761
# CostChange         NaN
